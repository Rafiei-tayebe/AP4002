# %%
# functional programming
# object oriented programming

# web scraping
    # requests & BeautifulSoup 
    # selenium

# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get('https://www.tgju.org/')

# %%
print(page)
# Out:
# <Response [200]>

# %%
print(page.text)
# Out:
# <!doctype html>
# <html dir="rtl" data-dir="rtl" lang="fa" data-revision="202205078">
# <head>
# <title>قیمت طلا, قیمت سکه, قیمت دلار - شبکه اطلاع رسانی طلا و ارز</title>
# <meta charset="utf-8">
# <script src="/cdn-cgi/apps/head/2-TH869l7meD3xSLuMby-2U21iU.js"></script><link rel="preconnect" href="https://static.accessban.com">
# <link rel="preconnect" href="https://call.tgju.org">
# <link rel="dns-prefetch" href="https://static.accessban.com">
# <link rel="dns-prefetch" href="https://call.tgju.org">
# <meta name="generator" content="Vandaw Parin 2.0 (vandaw.com/parin)">
# <link rel="search" type="application/opensearchdescription+xml" href="https://www.tgju.org/opensearch.xml" title="TGJU">
# <base href="https://www.tgju.org/">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <meta name="theme-color" content="#35608c">
# <link rel="apple-touch-icon" sizes="180x180" href="https://www.tgju.org/touch-icon-ipad.png">
# <meta name="robots" content="index, follow">
# <meta name="apple-mobile-web-app-capable" content="yes">
# <meta name="description" content="">
# <meta name="keywords" content="">
# <meta property="og:site_name" content="شبکه اطلاع رسانی طلا و ارز">
# <meta property="og:title" content="قیمت طلا, قیمت سکه, قیمت دلار - شبکه اطلاع رسانی طلا و ارز">
# <meta property="og:locale" content="fa_IR">
# <meta property="og:url" content="https://www.tgju.org/">
# <meta property="og:type" content="website">
# <meta property="og:description" content="">
# <meta name="twitter:card" content="summary">
# <meta name="twitter:title" content="قیمت طلا, قیمت سکه, قیمت دلار - شبکه اطلاع رسانی طلا و ارز">
# <meta name="twitter:site" content="@tgjuofficial">
# <meta name="twitter:creator" content="@tgjuofficial">
# <meta name="twitter:description" content="">
# <link rel="canonical" href="https://www.tgju.org/">
# <link rel="stylesheet" href="https://static.accessban.com/views/default/css/init-new.css?revision=00004414.css">
# <script data-cfasync="false" src="https://static.accessban.com/views/default/js/init.js?revision=00004414.js" defer></script>
# <style>
# 		@font-face {
# 			font-family: iranyekan;
# 			font-style: normal;
# 			font-weight: 700;
# 			src: url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/eot/iranyekanwebbold(fanum).eot");
# 			src: url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/eot/iranyekanwebbold(fanum).eot?#iefix") format("embedded-opentype"), url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/woff2/iranyekanwebbold(fanum).woff2") format("woff2"), url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/woff/iranyekanwebbold(fanum).woff") format("woff"), url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/ttf/iranyekanwebbold(fanum).ttf") format("truetype")
# 		}
#
# 		@font-face {
# 			font-family: iranyekan;
# 			font-style: normal;
# 			font-weight: 400;
# 			src: url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/eot/iranyekanwebregular(fanum).eot");
# 			src: url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/eot/iranyekanwebregular(fanum).eot?#iefix") format("embedded-opentype"), url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/woff2/iranyekanwebregular(fanum).woff2") format("woff2"), url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/woff/iranyekanwebregular(fanum).woff") format("woff"), url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/ttf/iranyekanwebregular(fanum).ttf") format("truetype")
# 		}
#
# 		@font-face {
# 			font-family: fontawesome;
# 			src: url("https://static.accessban.com/views/default/css/font-awesome-4.5.0/fonts/fontawesome-webfont.eot");
# 			src: url("https://static.accessban.com/views/default/css/font-awesome-4.5.0/fonts/fontawesome-webfont.eot?#iefix&v=4.0.3") format("embedded-opentype"), url("https://static.accessban.com/views/default/css/font-awesome-4.5.0/fonts/fontawesome-webfont.woff") format("woff"), url("https://static.accessban.com/views/default/css/font-awesome-4.5.0/fonts/fontawesome-webfont.ttf") format("truetype"), url("https://static.accessban.com/views/default/css/font-awesome-4.5.0/fonts/fontawesome-webfont.svg#fontawesomeregular") format("svg");
# 			font-weight: 400;
# 			font-style: normal
# 		}
# 		</style>
# <!--[if lt IE 9]>
# 	<script src="components/fallback/html5shiv.js"></script>
# 	<script src="components/fallback/respond.min.js"></script>
# 	<![endif]-->
# <script type="application/ld+json">
# 			{
# 				"@context": "https://schema.org/",
# 				"@type": "WebSite",
# 				"name": "شبکه اطلاع رسانی طلا و ارز",
# 				"url": "https://www.tgju.org/",
# 				"potentialAction": {
# 					"@type": "SearchAction",
# 					"target": "https://www.tgju.org/search?q={query}",
# 					"query": "required",
# 					"query-input": "required name=query"
# 				}
# 			}
# 			</script>
# <script data-dashboard-remove="true" src="https://www.gstatic.com/firebasejs/8.4.2/firebase-app.js"></script>
# <script data-dashboard-remove="true" src="https://www.gstatic.com/firebasejs/8.4.2/firebase-messaging.js"></script>
# <script data-dashboard-remove="true" src="https://www.gstatic.com/firebasejs/8.4.2/firebase-analytics.js"></script>
# <script type="application/ld+json">
# 			{
# 				"@context": "https://schema.org/",
# 				"@type": "Organization",
# 				"name": "شبکه اطلاع رسانی طلا و ارز",
# 				"legalName": "شبکه اطلاع رسانی طلا و ارز",
# 				"url": "https://www.tgju.org",
# 				"@id": "https://www.tgju.org",
# 				"logo": "https://www.tgju.org/touch-icon-ipad.png",
# 				"actionableFeedbackPolicy": "https://www.tgju.org/form/report",
# 				"correctionsPolicy": "https://www.tgju.org/terms",
# 				"knowsAbout": "وب سایت قیمت ها",
# 				"publishingPrinciples": "https://www.tgju.org/terms",
# 				"alternateName": "TGJU",
# 				"foundingDate": "2011-01-01T00:00:00.000Z",
# 				"image":"https://static.accessban.com/images/tgju-sc.jpg",
# 				"email": "info@tgju.org",
# 				"description": "سامانه جامع پایش، گردآوری، پردازش و انتشار قیمت‌ها و انواع داده‌های اقتصادی و مالی از انواع بورس‌ها و بازارهای ارزی، کالایی، سهام، اوراق، فلزات و مسکوکات، انرژی، صندوق‌های سرمایه‌گذاری و ارزهای دیجیتال (رمز ارزها) در عرصه داخلی و جهانی",
# 				"telephone": "+982191010004",
# 				"address": {
# 				  "@type": "PostalAddress",
# 				  "streetAddress": "North Sohrevardi St - Kourosh St - Number 66 - Floor 6 - Unite 8",
# 				  "addressLocality": "Tehran",
# 				  "addressRegion": "TEH",
# 				  "postalCode": "1559713820",
# 				  "addressCountry": "IR"
# 				},
# 				"contactPoint": {
# 				  "@type": "ContactPoint",
# 				  "contactType": "پشتیبانی",
# 				  "telephone": "+982191014609",
# 				  "contactOption": "",
# 				  "email": [
# 					  "info@tgju.org",
# 					  "support@tgju.org",
# 					  "content@tgju.org",
# 					  "technical@tgju.org",
# 					  "sales@tgju.org",
# 					  "design@tgju.org",
# 					  "finance@tgju.org",
# 					  "admin@tgju.org"
# 				  ]
# 				},
# 				"sameAs": [
# 				  "https://www.facebook.com/TgjuSocialMedia/",
# 				  "https://twitter.com/TgjuSocialMedia",
# 				  "https://www.linkedin.com/company/tgjusocialmedia",
# 				  "https://www.instagram.com/tgjusocialmedia/",
# 				  "https://www.tiktok.com/@tgjusocial",
# 				  "https://www.twitch.tv/tgjusocialmedia",
# 				  "https://www.reddit.com/user/TgjuSocialMedia",
# 				  "http://tgjusocialmedia.tumblr.com/",
# 				  "https://www.pinterest.com/TgjuSocialMedia/",
# 				  "https://vimeo.com/tgjusocialmedia",
# 				  "https://www.youtube.com/channel/UCGSWju3USoS_JuOtVnu8I9Q"
# 				  ]
# 			  }
# 			</script>
# <link rel="shortcut icon" href="https://static.accessban.com/views/default/images/favicon.ico">
#
#
# <script data-cfasync="false">
# 		function trans(key) {
# 	var translations = {
# 		'profile.loading': "در حال بارگزاری ...",
# 		'master.search-placeholder-all': "عبارتی را برای جستجو وارد نمایید ...",
# 		'master.search-placeholder-others': "جستجو در",
# 		'world_market.in': "در",
# 		'master.bazare_dakheli': "بازار داخلی",
# 		'master.bazare_jahani': "بازار جهانی",
# 		'master.profile': "پروفایل",
# 		'profile.history': "تاریخچه",
# 		'headermenu.gm2_2': "شاخص‌های اقتصادی",
# 		'profile.technical': "تکنیکال",
# 		'diagrams.bazar_khordeforooshi': "بازارهای خرده فروشی",
# 		'master.search-akhbar_va_maghalat': "اخبار و مقالات",
# 		'master.rahnama_va_amozesh': "راهنما و آموزش",
# 		'profile.chart': "نمودار",
# 		'master.your_search_title_was_not_found': "عنوان جستجو شده شما یافت نشد"
# 	};
#
# 	return ( typeof translations[key] != 'undefined' ) ? translations[key] : key;
# }
# 		var hide_items_str = 'transfer_usd,transfer_usd2,transfer_eur,transfer_eur2,transfer_gbp,transfer_aed,transfer_cny,transfer_myr,transfer_try,transfer_try2,transfer_cad,transfer_aud,transfer_nzd,transfer_jpy,transfer_rub,transfer_inr,transfer_sek,transfer_chf,transfer_omr,transfer_kwd,transfer_turkey_dollar,transfer_afghan_dollar,transfer_georgia_dollar,price_dollar_sm_future,price_dollar_afshar_future,price_dollar_sm,price_dollar_afshar,price_eur_ex,price_dollar_ex,price_dollar_future,price_mashhad_dollar,price_shiraz_dollar,price_marivan_dollar,price_baneh_dollar,price_piranshahr_dollar,price_istanbul_dollar,price_dubai_dollar,price_tbilisi_dollar,gold_checkout,coin_checkout,nima_buy_chf,nima_buy_gbp,nima_buy_cad,nima_buy_sek,nima_buy_nok,nima_buy_azn,nima_sell_sek,nima_sell_nok,nima_sell_azn,price_bam,price_bch,price_awg,price_btn,price_cdf,price_crc,price_cve,price_cyp,price_eos,price_etc,price_gnt';
# 		window.hide_items = hide_items_str.split(',');
#
# 		var is_dark_excluded = false;
# 		var is_darkmode = decodeURIComponent(document.cookie).indexOf('dark-mode-enabled=true') !== -1;
# 		if ( is_darkmode && !is_dark_excluded ) {
# 			document.getElementsByTagName('html')[0].className += ' dark';
# 		}
#
# 		window.is_darkmode = function () {
# 			return document.querySelector('html').classList.contains('dark');
# 		}
#
# 		var site_name = 'tgju';
# 		var site_mode = 'main';
#
#
# 					var popup_ad = {
# 						url: "https://www.instagram.com/tgjusocialmedia/",
# 						img: "https://static.accessban.com/advertisement/mbs291afet5x.gif",
# 						width: "640px"
# 					};
#
# 					var floating_ad = false;
#
# 		/**
# 		 * کد عمومی آگهی
# 		 */
# 		var advertise_to_load = [];
# 		var advertise_items = [];
# 		function advertise_region(place_id) {
# 			advertise_to_load.push(place_id);
# 		}
# 		function advertise_show() {
# 			if (advertise_to_load && advertise_to_load.length) {
# 				$.ajax({
# 					'url': 'https://api.accessban.com/v1/advertisement/place?places=' + advertise_to_load.join(','),
# 					'success': function(result) {
# 						if (result && result.response && result.response.length) {
# 							result.response = shuffle(result.response);
# 							for(var i in result.response) {
# 								var item = result.response[i];
# 								var el = $('[data-advertise-id="'+item.type+'"]');
# 								if (el.length) {
# 									if (el.attr('data-advertise-limit')) {
# 										var limit = parseInt(el.attr('data-advertise-limit'));
#
# 										if (el.find('li').length === limit) {
# 											continue;
# 										}
# 									}
#
# 									el.append('<li data-place-name="'+ item.name +'" class="show">'
# 										+ '<a target="_blank" href="'+ item.url +'">'
# 											+ '<img src="'+ item.image +'" alt="">'
# 										+ '</a>'
# 									+ '</li>');
# 								}
# 							}
# 						}
# 					}
# 				});
# 			}
# 		}
# 	</script>
# <script>
# 		var trans_loading = "در حال بارگزاری ...";
# 		var parin_lang = 'fa';
# 		window.source_price = new Object();
#
# 		var platform_info = {};
# 		var platform_info_done = false;
# 		// var url = "https://platform.tgju.org/info.php";
# 		// if (window.XDomainRequest && detectIE()) {
# 		// 	var xdr = new XDomainRequest();
# 		// 	xdr.open("GET", url, false);
# 		// 	xdr.onload = function () {
# 		// 		var res = JSON.parse(xdr.responseText);
# 		// 		if (res == null || typeof (res) == 'undefined')
# 		// 		{
# 		// 			res = JSON.parse(data.firstChild.textContent);
# 		// 		}
# 		// 		publishData(res);
# 		// 	};
# 		// 	xdr.send();
# 		// } else {
# 		// 	var xmlhttp = new XMLHttpRequest();
# 		// 	xmlhttp.onreadystatechange = function() {
# 		// 	if (xmlhttp.readyState == 4) {
# 		// 		if (xmlhttp.status == 200 || xmlhttp.status == 304) {
# 		// 		publishData(JSON.parse(xmlhttp.responseText));
# 		// 		} else {
# 		// 		setTimeout(function(){ console.log("Request failed!") }, 0);
# 		// 		}
# 		// 	}
# 		// 	}
# 		// 	xmlhttp.open("GET", url, true);
# 		// 	xmlhttp.send();
# 		// }
#
#
#
#
#
# 		// یکتانت
# 		// $(document).ready(function() {
# 		// 	if ( $(window).width() < 760 && $('#advertise-place-25').length ) {
# 		// 		(function () {
# 		// 			var now = new Date();
# 		// 			var head = document.getElementsByTagName('head')[0];
# 		// 			var script = document.createElement('script');
# 		// 			script.type = 'text/javascript';
# 		// 			script.async = true;
# 		// 			script.src =
# 		// 				'https://cdn.yektanet.com/template/bnrs/yn_bnr.min.js?v=' +
# 		// 				now.getFullYear() +
# 		// 				'0' +
# 		// 				now.getMonth() +
# 		// 				'0' +
# 		// 				now.getDate() +
# 		// 				'0' +
# 		// 				now.getHours();
# 		// 			head.appendChild(script);
# 		// 		})();
# 		// 	}
# 		// });
#
#
#
#
# 		window.WhelpConfig = {
# 			app_id: '9d382a9deaf55bb4a3c81f65e39ae260'
# 		};
#
# 		// function get_notification() {
# 		// }
#
#
# 	</script>
# <script data-cfasync="false" src="https://static.accessban.com/public/jquery-2.2.4.min.js"></script>
#
#
#
# <style>
# 				.advertise.place-2 img,
# 		.advertise.place-2 object {
# 		    height: 190px;
# 		 }
# 			</style>
# <style>
# 		@media (min-width: 1023px) {
# 			.header-statement {
# 				display: none !important;
# 			}
# 		}
# 		@media only screen and (max-width: 1023px) {
# 			.top-iwmf {
# 				display: none;
# 			}
#
# 			/*.header-statement {
# 				display: block !important;
# 			}*/
# 		}
# 		@media only screen and (max-width: 760px) {
# 			.header-statement {
# 				margin-bottom:10px ;
# 			}
# 		}
# 		.header-statement {
# 			font-size: 15px;
# 			padding: 11px;
# 			font-weight: 600;
# 			background: #f4d88f;
# 			color: #482801;
# 			position: relative;
# 		}
#
# 		.header-statement:before {
# 			content: '';
# 			display: block;
# 			background: url("https://static.accessban.com/images/icon-background-pt1.png");
# 			position: absolute;
# 			left: 0;
# 			right: 0;
# 			bottom: 0;
# 			top: 0;
# 			opacity: 0.12;
# 		}
#
# 		.header-statement-wrapper {
# 			position: relative;
# 			z-index: 1;
# 			display: flex;
# 			justify-content: center
# 		}
#
# 		.header-statement img {
# 			float: right;
# 			margin-top: 5px;
# 			margin-left: 10px;
# 		}
#
# 		.header-statement a {
# 			color: #111;
# 		}
#
# 			.header-statement a.more-button {
# 				background: rgba(0,0,0,.6);
# 				display: inline-block;
# 				margin-right: 5px;
# 				border-radius: 3px;
# 				color: white;
# 				padding: 0px 8px 1px;
# 			}
#
# 		.header-statement strong {
# 			background: rgba(100, 50, 0, 0.5);
# 			padding: 5px 7px 6px;
# 			border-radius: 4px;
# 			font-size: 14px;
# 			color: #fff;
# 			display: inline-block;
# 			line-height: 1;
# 		}
# 		@media only screen and (max-width: 760px) {
# 			table thead th .h2 a {
# 				color: #fff !important;
# 			}
# 		}
# 		@media only screen and (max-width: 500px) {
# 			.header-statement img
# 			{
# 			}
# 			.header-statement-wrapper{
# 				font-size: 11px;
# 				align-items: center;
# 				white-space: nowrap;
# 			}
# 		}
#
# 		.iwmf-text,
# 		.header-statement-wrapper
# 		{
# 			color: #482801;
# 		}
#
# 		ul.header-breadcrumb-news-line {
#
# 		}
#
# 		ul.header-breadcrumb-news-line li {
# 			display: none;
# 		}
#
# 		ul.header-breadcrumb-news-line li.active {
# 			display: block;
# 		}
# 	</style>
# <meta name="insight-app-sec-validation" content="7ad9f89b-a2a1-4b97-8bf9-64cc34c54323">
# <script>
# 	function viewport_size() {
# 		var win = window,
# 		doc = document,
# 		docElem = doc.documentElement,
# 		body = doc.getElementsByTagName('body')[0],
# 		x = win.innerWidth || docElem.clientWidth || body.clientWidth,
# 		y = win.innerHeight|| docElem.clientHeight|| body.clientHeight;
# 		return x;
# 	}
# 	</script>
# <script async src='/cdn-cgi/challenge-platform/h/g/scripts/invisible.js?ts=1651892400'></script></head>
# <body class="homepage   fs-grid  ">
# <img src="https://static.accessban.com/advertisement/mbs291afet5x.gif" alt="" style="display: none;">
# <div id="server-time" data-value="2022-05-07 3:30:40" data-server="2022-05-07 3:30:40"></div>
# <div class="">
# <header id="main-header" class="widgets header-top-tools main-tgju">
#
#
# <div class="header-statement">
# <ul class="header-breadcrumb-news-line header-statement-wrapper">
# </ul>
# </div>
# <div class="header">
# <div class="menu-btn header-bar" onclick="header_bar('click', true);">
# <span class="lines">
# <i></i>
# <i></i>
# <i></i>
# </span>
# </div>
# <div class="bar-menu " onmouseover="header_bar('hover')">
# </div>
#
# <a href="." class="sitename">
# <div class="header-logo">
# <div class="head-logo"><img src="https://www.tgju.org/touch-icon-ipad.png" alt="TGJU"></div>
# <div class="header-logo-title">
# <span class="title">شبکه اطلاع رسانی</span>
# <span class="description">طـــــــــــلا، ســکـــــــــــه و ارز</span>
# </div>
# </div>
# </a>
# <div class="top-btn-menu">
# <div class="top-btn-icon top-btn-icon-add">
# <div class="top-btn-icon-i"></div>
# <div class="throb-head"></div>
# </div>
# <div class="top-btn-menu-box" id="top-btn-menu-box">
#
# </div>
# <div class="top-btn-menu-box-bg"></div>
# </div>
# <div class="search-res-btn"></div>
# <div class="search search-hide">
# <div class="search-container">
# <input type="text" class="search-input" placeholder="جستجو در سایت" value="">
# <select class="search-select">
# <option class="search-option" value="all" selected>کلیه موارد</option>
# <option class="search-option" value="markets.internal">بازار داخلی</option>
# <option class="search-option" value="crypto">بازار ارزهای دیجیتال</option>
# <option class="search-option" value="markets.stocks">بورس</option>
# <option class="search-option" value="markets.global">بازار جهانی</option>
# <option class="search-option" value="economics.country">اقتصاد کشورها</option>
# <option class="search-option" value="economics.index">شاخص‌های اقتصادی</option>
# <option class="search-option" value="economics.forecast">پیش بینی‌ها</option>
# <option class="search-option" value="news">اخبار و مقالات</option>
# <option class="search-option" value="solutions.farsi">راهنما و آموزش</option>
# </select>
# <div class="search-box-header search-box-wrapper bootstrap-fix">
# <div class="search-box-before"></div>
# <div class="search-result row search-tabs">
# <div class="col-12 col-md-12 col-lg-12 search-result-content" style="padding: 0 !important;">
# <div class="search-result-content-head" style="display: none">
# <div class="search-result-title">نتیجه جستجو :</div>
# <div class="search-result-tabs">
# <span class="result-search-tab">نتایج جستجو</span>
# <span class="news-search-tab">اخبار و مقالات</span>
# </div>
# </div>
# <div class="search-result-content-data scrollbar-min">
# </div>
# <div class="search-result-content-footer">
# <a href="#" target="_blank" style="visibility: hidden">
# <i class="fa fa-search" aria-hidden="true"></i>
# مشاهده نتیجه کامل جستجوی: <span class="search-result-keyword"></span>
# </a>
# </div>
# </div>
#
# </div>
# </div>
# </div>
# <div class="search-exit"></div>
# </div>
# <div class="advertising">
# <ul class="advertise place-header" id="advertise-place-6" style="margin-bottom: 0 !important;margin-top: 0 !important;">
# <li data-row="0" data-place-name="O" class="show"><a target="_blank" href="https://tabdeal.org/?utm_source=tgju&utm_medium=display&utm_campaign=tgju_fixbnr_brnd_asli"><img id="ad-7lztejx1r64mcqwou0wl" src="..." data-ad-img-src="https://static.accessban.com/advertisement/edsfn9k4b7z6.gif" alt="تبدیل" class="ad-hide"></a><script>
# 				ad = document.getElementById("ad-7lztejx1r64mcqwou0wl");
# 				if ((ad.parentNode.parentNode.parentNode.className.indexOf("advertise-mobile") !== -1 && viewport_size() < 758)
# 					|| (ad.parentNode.parentNode.parentNode.className.indexOf("advertise-mobile") === -1 && viewport_size() > 758)
# 					|| (ad.parentNode.parentNode.parentNode.className.indexOf("advertise-all") !== -1)
# 				) {
# 					ad.setAttribute("src", ad.getAttribute("data-ad-img-src"));
# 					ad.setAttribute("class", "");
# 				}
# 				</script></li> </ul>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="header-navbar">
# <div class="nav-links">
# <div class="finder">
# <div onclick="$('#indicator-modal').show(); if ( $('#indicator-modal #columns2').html() == '' ) { diagrams_render2(); }"><i class="fa fa-th" aria-hidden="true"></i> <span class="indicator-btn-title" style="display:inline-block;">شاخص یاب</span></div>
# </div>
# <div class="header-links header-menus">
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li data-name="gold" itemprop="name">
# <a itemprop="url" href="">طلا و ارز</a>
# <div class="section"><div>
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li class="header-links-icon">
# <span class="item-1"></span>
# </li>
# <li>
# <a href="gold-chart">قیمت طلا</a>
# <ul>
# <li itemprop="name"><a itemprop="url" href="gold-chart">نمای کلی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/mesghal">مثقال طلا</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/geram18">طلای 18 عیار</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/geram24">طلای 24 عیار</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gold_mini_size/technical">طلای دست دوم</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="gold-chart">مشاهده کلیه شاخص ها</a></li>
# </ul>
# <a href="currency">نرخ ارز</a>
# <ul>
# <li itemprop="name"><a itemprop="url" href="currency">نمای کلی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_dollar_rl">دلار</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_eur">یورو</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_gbp">پوند</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_aed">درهم امارات</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="currency">مشاهده سایر ارزها</a></li>
# </ul>
# </li>
# <li>
# <a href="gold-chart">قیمت آبشده</a>
# <ul>
# <li itemprop="name"><a itemprop="url" href="gold-chart">نمای کلی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gold_futures">آبشده نقدی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gold_melted_wholesale">آبشده بنکداری</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gold_world_futures">آبشده کمتر از کیلو</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gold_melted_transfer">آبشده شنبه ای</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="gold-chart">مشاهده کلیه شاخص ها</a></li>
# </ul>
# <a href="bank">ارز مبادله ای</a>
# <ul>
# <li itemprop="name"><a itemprop="url" href="bank">نمای کلی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/bank_usd">دلار</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/bank_eur">یورو</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/bank_gbp">پوند</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/bank_aed">درهم امارات</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="bank">مشاهده سایر ارزهای مبادله ای</a></li>
# </ul>
# </li>
# <li>
# <a href="coin">قیمت سکه</a>
# <ul>
# <li itemprop="name"><a itemprop="url" href="coin">نمای کلی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/sekeb">سکه بهار آزادی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/sekee">سکه امامی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/nim">نیم سکه</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/rob">ربع سکه</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gerami">سکه گرمی</a></li>
# </ul>
# <a href="sana">ارز سنا</a>
# <ul>
# <li itemprop="name"><a itemprop="url" href="sana">نمای کلی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/sana_sell_usd">دلار</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/sana_sell_eur">یورو</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/sana_sell_gbp">پوند</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/sana_sell_aed">درهم امارات</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="sana">مشاهده سایر ارز های سنا</a></li>
# </ul>
# </li>
# <li>
#
#
# <ul>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="قیمت-دلار">قیمت دلار</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="diamond">قیمت برلیان</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="profile/silver_999">قیمت نقره</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="coin">سکه در بورس</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="gold-chart">طلا در بورس</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="coin">قیمت سکه تاریخ پایین</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="coin">قیمت سکه تک فروشی</a></li>
# </ul>
# <a href="نرخ-ارز-نیمایی" style="margin-top: 5px;">ارز نیما</a>
# <ul>
# <li itemprop="name"><a itemprop="url" href="نرخ-ارز-نیمایی">نمای کلی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/nima_sell_usd">دلار</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/nima_sell_eur">یورو</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/nima_sell_gbp">پوند</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/nima_sell_aed">درهم امارات</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="نرخ-ارز-نیمایی">مشاهده سایر حواله های ارزی</a></li>
# </ul>
# </li>
# </ul>
# </div></div>
# </li>
# <li onmouseover="load_header_links(this, 'cryptomenu');" data-header-links="cryptomenu" data-name="cryptomenu" itemprop="name">
# <a itemprop="url" href="crypto">ارز دیجیتال
#
# </a>
# <div class="section"><div></div></div>
# </li>
# <li data-name="stocks" itemprop="name">
# <a itemprop="url" href="https://www.shakhesban.com/markets/stock">بورس </a>
# </li>
#
#
# <li onmouseover="load_header_links(this, 'markets-new');" data-header-links="markets-new" data-name="markets" itemprop="name">
# <a itemprop="url" href="local-markets">بازار داخلی</a>
# <div class="section"><div>
# <ul>
# <li class="header-links-icon header-links-icon-with-tab header-links-icon-big">
# <div class="header-links-tabs iran-markets-tab">
# <ul>
# <li class="active">
# <a onclick="header_links_tab(this, 3, 'markets-new-1'); return false;" href="#">
# <span class="header-links-tabs-sprite-img" style="background-position: -704px -383px;"></span>بازار ارز
# </a>
# </li>
# <li>
# <a onclick="header_links_tab(this, 3, 'markets-new-2'); return false;" href="#">
# <span class="header-links-tabs-sprite-img" style="background-position: -733px -458px;"></span>بازار طلا و سکه
# </a>
# </li>
# <li>
# <a onclick="header_links_tab(this, 3, 'markets-new-3'); return false;" href="#">
# <span class="header-links-tabs-sprite-img" style="background-position: -325px -369px;"></span>بازار بورس
# </a>
# </li>
# </ul>
# </div>
# </li>
#
# <li data-header-links-tab="markets-new-1">
# <a class="header-link-plus" href="currency">نرخ ارزها</a>
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a itemprop="url" href="currency">نمای کلی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_dollar_rl" target="_blank">دلار</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_eur" target="_blank">یورو</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_aed" target="_blank">درهم امارات</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_gbp" target="_blank">پوند انگلیس</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_sek" target="_blank">کرون سوئد</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_nok" target="_blank">کرون نروژ</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="currency">مشاهده کلیه ارز‌های آزاد</a>
# </ul>
# <a class="header-link-plus" href="sana">قیمت ارز سنا</a>
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a itemprop="url" href="sana">نمای کلی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/sana_sell_usd">دلار</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/sana_sell_eur">یورو</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/sana_sell_gbp">پوند</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/sana_sell_aed">درهم امارات</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/sana_sell_cad">دلار کانادا</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/sana_sell_try">لیر ترکیه</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="sana">مشاهده کلیه ارز‌های سنا</a>
# </ul>
# </li>
# <li data-header-links-tab="markets-new-1">
# <a class="header-link-plus" href="currency">نرخ ارزها</a>
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a itemprop="url" href="profile/price_jpy" target="_blank">ین ژاپن</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_myr" target="_blank">رینگیت مالزی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_kwd" target="_blank">دینار کویت</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_syp" target="_blank">لیر سوریه</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_rub" target="_blank">روبل روسیه</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_omr" target="_blank">ریال عمان</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_sgd" target="_blank">دلار سنگاپور</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="currency">مشاهده کلیه ارز‌های آزاد</a>
# </ul>
# <a class="header-link-plus" href="نرخ-ارز-نیمایی">قیمت ارز نیما</a>
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a itemprop="url" href="sana">نمای کلی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/nima_buy_usd">دلار</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/nima_buy_eur">یورو</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/nima_buy_gbp">پوند</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/nima_buy_aed">درهم امارات</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/nima_buy_cad">دلار کانادا</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/nima_buy_try">لیر ترکیه</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="نرخ-ارز-نیمایی">مشاهده کلیه ارزهای نیما</a></li>
# </ul>
# </li>
# <li data-header-links-tab="markets-new-1">
# <a class="header-link-plus" href="currency">نرخ ارزها</a>
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a itemprop="url" href="profile/price_iqd" target="_blank">دینار عراق</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_afn" target="_blank">افغانی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_rub" target="_blank">روبل روسیه</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_azn" target="_blank">منات آذربایجان</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_bhd" target="_blank">دینار بحرین</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_afn" target="_blank">لاری گرجستان</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/price_sar" target="_blank">ریال عربستان</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="bank">مشاهده کلیه ارز‌های آزاد</a>
# </ul>
# <a class="header-link-plus" href="bank">قیمت ارز بانکی</a>
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a itemprop="url" href="bank">نمای کلی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/bank_usd">دلار</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/bank_eur">یورو</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/bank_gbp">پوند</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/bank_cny">یوان چین</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/bank_try">لیر ترکیه</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/bank_aed">درهم امارات</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="bank">مشاهده کلیه ارزهای بانکی</a>
# </ul>
# </li>
# <li data-header-links-tab="markets-new-1">
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li class="active"><a class="header-link-plus" href="currency">قیمت ارزهای آزاد</a></li>
# <li class="active"><a class="header-link-plus" href="sana">قیمت ارزهای سنا</a></li>
# <li class="active"><a class="header-link-plus" href="نرخ-ارز-نیمایی">قیمت ارزهای نیما</a></li>
# <li class="active"><a class="header-link-plus" href="bank">قیمت ارز های بانکی</a></li>
# <li class="active"><a class="header-link-plus" href="transfer">قیمت حوالجات ارزی</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="gold-chart">قیمت طلا</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="gold-chart">قیمت آبشده</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="coin">قیمت سکه</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="قیمت-سکه-پارسیان">قیمت سکه پارسیان</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="https://www.shakhesban.com/markets/all?flow=1">بازار بورس</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="https://www.shakhesban.com/markets/all?flow=2">بازار فرابورس</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="https://www.shakhesban.com/markets/index">شاخص ها</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="https://www.shakhesban.com/markets/stock">سهام</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="https://www.shakhesban.com/markets/fund">صندوق ها</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="https://www.shakhesban.com/markets/bond">اوراق</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="https://www.shakhesban.com/markets/future">بازار آتی ( فیوچر )</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="https://www.shakhesban.com/markets/option">بازار اختیار معامله( آپشن )</a></li>
# </ul>
# </li>
#
# <li data-header-links-tab="markets-new-2">
# <a href="gold-chart">قیمت طلا</a>
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a itemprop="url" href="profile/geram18">طلای 18 عیار</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/geram24">طلای 24 عیار</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gold_740k">طلای 18 عیار / 740</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gold_mini_size">طلای دست دوم</a></li>
# </ul>
# <a href="gold-chart">قیمت آبشده</a>
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a itemprop="url" href="profile/gold_futures">آبشده نقدی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gold_melted_wholesale">آبشده بنکداری </a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gold_world_futures">آبشده کمتر از کیلو</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gold_melted_transfer">آبشده شنبه ای </a></li>
# </ul>
# <a href="gold-chart">قیمت مثقال</a>
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a itemprop="url" href="profile/mesghal">مثقال طلا</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gold_17">مثقال / عیار جهانی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gold_17_transfer">مثقال / حواله دلار</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gold_17_coin">مثقال / حواله دلار</a></li>
# </ul>
# <a href="gold-chart">قیمت نقره</a>
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a itemprop="url" href="profile/silver_999">نقره ۹۹۹</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/silver_925">گرم نقره ۹۲۵</a></li>
# </ul>
# </li>
# <li data-header-links-tab="markets-new-2">
# <a href="coin">قیمت سکه معاملاتی</a>
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a itemprop="url" href="profile/sekeb">سکه بهار آزادی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/sekee">سکه امامی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/nim">نیم سکه</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/rob">ربع سکه</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gerami">سکه گرمی</a></li>
# </ul>
# <a href="coin">حباب سکه</a>
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a itemprop="url" href="profile/coin_blubber">حباب سکه امامی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/sekeb_blubber">حباب سکه بهار آزادی</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/nim_blubber">حباب نیم سکه</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/rob_blubber">حباب ربع سکه</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gerami_blubber">حباب سکه گرمی</a></li>
# </ul>
# <a href="coin">سکه در بورس</a>
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a itemprop="url" href="profile/gc9">سکه 1 روزه سامان</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gc7">سکه 1 روزه صادرات</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gc8">سکه 1 روزه آینده</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gc6">سکه 1 روزه ملت</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/gc5">سکه 1 روزه رفاه</a></li>
# </ul>
# </li>
# <li data-header-links-tab="markets-new-2">
# <a href="قیمت-سکه-پارسیان">سکه پارسیان</a>
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a itemprop="url" href="profile/سکه-پارسیان-۰-۱۰۰">سکه پارسیان 0/100</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/سکه-پارسیان-۰-۱۵۰">سکه پارسیان 0/150</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/سکه-پارسیان-۰-۲۰۰">سکه پارسیان 0/200</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/سکه-پارسیان-۰-۲۵۰">سکه پارسیان 0/250</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/سکه-پارسیان-۰-۳۰۰">سکه پارسیان 0/300</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/سکه-پارسیان-۰-۳۵۰">سکه پارسیان 0/350</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/سکه-پارسیان-۰-۴۰۰">سکه پارسیان 0/400</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/سکه-پارسیان-۰-۴۵۰">سکه پارسیان 0/450</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/سکه-پارسیان-۰-۵۰۰">سکه پارسیان 0/500</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/سکه-پارسیان-۰-۶۰۰">سکه پارسیان 0/600</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/سکه-پارسیان-۰-۷۰۰">سکه پارسیان 0/700</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/سکه-پارسیان-۰-۸۰۰">سکه پارسیان 0/800</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/سکه-پارسیان-۰-۹۰۰">سکه پارسیان 0/900</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/سکه-پارسیان-۱-۰۰۰">سکه پارسیان 1/000</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/سکه-پارسیان-۱-۱۰۰">سکه پارسیان 1/100</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/سکه-پارسیان-۱-۲۰۰">سکه پارسیان 1/200</a></li>
# <li itemprop="name"><a itemprop="url" href="profile/سکه-پارسیان-۱-۳۰۰">سکه پارسیان 1/300</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="قیمت-سکه-پارسیان">مشاهده کلیه سکه‌های پارسیان</a></li>
# </ul>
# </li>
# <li data-header-links-tab="markets-new-2">
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="currency">قیمت ارزهای آزاد</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="sana">قیمت ارزهای سنا</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="نرخ-ارز-نیمایی">قیمت ارزهای نیما</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="bank">قیمت ارز های بانکی</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="transfer">قیمت حوالجات ارزی</a></li>
# <li class="active"><a class="header-link-plus" href="gold-chart">قیمت طلا</a></li>
# <li class="active"><a class="header-link-plus" href="gold-chart">قیمت آبشده</a></li>
# <li class="active"><a class="header-link-plus" href="coin">قیمت سکه</a></li>
# <li class="active"><a class="header-link-plus" href="قیمت-سکه-پارسیان">قیمت سکه پارسیان</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="https://www.shakhesban.com/markets/all?flow=1">بازار بورس</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="https://www.shakhesban.com/markets/all?flow=2">بازار فرابورس</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="https://www.shakhesban.com/markets/index">شاخص ها</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="https://www.shakhesban.com/markets/stock">سهام</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="https://www.shakhesban.com/markets/fund">صندوق ها</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="https://www.shakhesban.com/markets/bond">اوراق</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="https://www.shakhesban.com/markets/future">بازار آتی ( فیوچر )</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="https://www.shakhesban.com/markets/option">بازار اختیار معامله( آپشن )</a></li>
# </ul>
# </li>
#
# <li data-header-links-tab="markets-new-3">
# <a class="header-link-plus" href="https://www.shakhesban.com/markets/stock?flow=1">بورس</a>
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/stock?flow=1">نمای کلی</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=1&sort=1&sort_type=desc">آخرین قیمت</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=1&sort=2&sort_type=desc">قیمت پایانی</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=1&sort=19&sort_type=desc">نوسان آخرین قیمت</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=1&sort=3&sort_type=desc">نوسان قیمت پایانی</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=1&sort=5&sort_type=desc">حجم معاملات</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=1&sort=6&sort_type=desc">ارزش معاملات</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=1&sort=4&sort_type=desc">تعداد معاملات</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=1&sort=20&sort_type=desc">ارزش بازار</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=1&sort=23&sort_type=desc">ارزش روز دارایی ها</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=1&sort=26&sort_type=desc">بدهی ها</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=1&sort=24&sort_type=desc">آخرین سرمایه</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=1&sort=25&sort_type=desc">حقوق صاحبان سهام</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=1&sort=27&sort_type=desc">درآمد پیش بینی</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=1&sort=21&sort_type=desc">P/E</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=1&sort=22&sort_type=desc">P/B</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="https://www.shakhesban.com/markets/all?flow=1">مشاهده کلیه نمادها</a></li>
# </ul>
# </li>
# <li data-header-links-tab="markets-new-3">
# <a class="header-link-plus" href="https://www.shakhesban.com/markets/stock?flow=2">فرابورس</a>
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/stock?flow=2">نمای کلی</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=2&sort=1&sort_type=desc">آخرین قیمت</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=2&sort=2&sort_type=desc">قیمت پایانی</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=2&sort=19&sort_type=desc">نوسان آخرین قیمت</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=2&sort=3&sort_type=desc">نوسان قیمت پایانی</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=2&sort=5&sort_type=desc">حجم معاملات</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=2&sort=6&sort_type=desc">ارزش معاملات</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=2&sort=4&sort_type=desc">تعداد معاملات</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=2&sort=20&sort_type=desc">ارزش بازار</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=2&sort=23&sort_type=desc">ارزش روز دارایی ها</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=2&sort=26&sort_type=desc">بدهی ها</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=2&sort=24&sort_type=desc">آخرین سرمایه</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=2&sort=25&sort_type=desc">حقوق صاحبان سهام</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=2&sort=27&sort_type=desc">درآمد پیش بینی</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=2&sort=21&sort_type=desc">P/E</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all?flow=2&sort=22&sort_type=desc">P/B</a></li>
# <li itemprop="name"><a itemprop="url" class="header-link-plus" href="https://www.shakhesban.com/markets/all?flow=2" target="_blank">مشاهده کلیه نمادها</a></li>
# </ul>
# </li>
# <li data-header-links-tab="markets-new-3">
# <a class="header-link-plus" href="https://www.shakhesban.com">بازار</a>
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com">نمای کلی بازار</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/stocks/codal">اطلاعیه های کدال</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/stocks/messages">پیام های ناظر</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/index">همه شاخص ها</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/all">همه نمادها</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/closedassets">نمادهای متوقف شده</a></li>
# <li itemprop="name"><a itemprop="url" href="https://www.shakhesban.com/markets/warrant">حق تقدم</a></li>
# <li itemprop="name"><a itemprop="url" href="coin-stocks">تابلوی معاملات آتی</a></li>
# <li itemprop="name"><a itemprop="url" href="option">تابلوی معاملات آپشن</a></li>
# <li itemprop="name"><a itemprop="url" href="brokers">فهرست کارگزاری ها</a></li>
# </ul>
# <a class="header-link-plus" href="bourse">داده های بنیادین</a>
# <ul itemscope itemtype="http://www.schema.org/SiteNavigationElement">
# ...
# <span>پشتیبانی هوشمند</span>
# </a>
# </li>
# <li class="side-buttons-14 side-buttons-chat">
# <a href="javascript: void(0);" onclick="open_support_chat();" class="a" style="background: #afafaf !important;">
# <svg xmlns="http://www.w3.org/2000/svg" style="width: 26px;fill: #fff;margin: 2px 8px;" viewBox="0 0 512 512"><path d="M360 144h-208C138.8 144 128 154.8 128 168S138.8 192 152 192h208C373.3 192 384 181.3 384 168S373.3 144 360 144zM264 240h-112C138.8 240 128 250.8 128 264S138.8 288 152 288h112C277.3 288 288 277.3 288 264S277.3 240 264 240zM447.1 0h-384c-35.25 0-64 28.75-64 63.1v287.1c0 35.25 28.75 63.1 64 63.1h96v83.1c0 9.836 11.02 15.55 19.12 9.7l124.9-93.7h144c35.25 0 64-28.75 64-63.1V63.1C511.1 28.75 483.2 0 447.1 0zM464 352c0 8.75-7.25 16-16 16h-160l-80 60v-60H64c-8.75 0-16-7.25-16-16V64c0-8.75 7.25-16 16-16h384c8.75 0 16 7.25 16 16V352z"></path></svg>
# <span>پشتیبانی آنلاین</span>
# </a>
# </li>
# </ul>
# </div>
# <div class="modal fade" id="bug-report-modal" tabindex="-1" role="dialog" style="display: none;">
# <div class="modal-dialog-box" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <a href="#" class="modal-close" onclick="$(this).parents('.modal').eq(0).toggle(); return false;" data-dismiss="modal" aria-label="Close">
# <span aria-hidden="true">×</span>
# </a>
# <div class="modal-title">گزارش خطا</div>
# <div style="clear: both"></div>
# </div>
#  <div id="tgju-crm-from-33"></div>
# </div>
# </div>
# </div>
#
#
#
#
# <div id="parin-loading"><span></span></div>
# <script>
# 				//var crypto_title_set = false;
# 				$(document).ready(function () {
# 					var transfer_usd = window.source_price['price_dollar_realtime'];
# 					var crypto_bitcoin_irr = window.source_price['crypto-bitcoin-irr'];
# 					var crypto_ethereum_irr = window.source_price['crypto-ethereum-irr'];
# 					var crypto_dash_irr = window.source_price['crypto-dash-irr'];
# 					var crypto_ripple_irr = window.source_price['crypto-ripple-irr'];
# 					var crypto_litecoin_irr = window.source_price['crypto-litecoin-irr'];
# 					var crypto_stellar_irr = window.source_price['crypto-stellar-irr'];
# 					var crypto_tether_irr = window.source_price['crypto-tether-irr'];
#
# 					/*
# 					$('table.market-table.crypto-table thead tr').each(function () {
# 						$(this).find('th').eq(1).after('<th>قیمت / ریال</th>');
# 					});
# 					$('table.market-table.crypto-table tbody tr').each(function () {
# 						var val = parseFloat($(this).find('td.nf').eq(0).text());
# 						val = Math.round(parseInt(val * transfer_usd) / 1000) * 1000;
#
# 						if ( $(this).attr('data-market-row') == 'crypto-bitcoin' ) {
# 							val = crypto_bitcoin_irr;
# 						} else if ( $(this).attr('data-market-row') == 'crypto-ethereum' ) {
# 							val = crypto_ethereum_irr;
# 						} else if ( $(this).attr('data-market-row') == 'crypto-dash' ) {
# 							val = crypto_dash_irr;
# 						} else if ( $(this).attr('data-market-row') == 'crypto-ripple' ) {
# 							val = crypto_ripple_irr;
# 						} else if ( $(this).attr('data-market-row') == 'crypto-litecoin' ) {
# 							val = crypto_litecoin_irr;
# 						} else if ( $(this).attr('data-market-row') == 'crypto-stellar' ) {
# 							val = crypto_stellar_irr;
# 						} else if ( $(this).attr('data-market-row') == 'crypto-tether' ) {
# 							val = crypto_tether_irr;
# 						}
#
# 						$(this).find('td.nf').eq(0).after('<td>' + number_format(val) + '</td>');
# 					});
#
# 					crypto_title_set = true;
# 					*/
#
# 					if ($(window).width() < 760) {
# 						// $('[data-market-row="price_dollar_rl"]').remove();
# 						// $('[data-market-row="price_dollar_dt"]').attr('data-market-row', 'price_dollar_rl');
#
# 						// -------
#
# 						$('.mobile-quickview').show();
#
# 						var mobile_quickview = '';
# 						var mobile_quickview_items = {
# 							price_dollar_rl: 'دلار',
# 							sekee: 'سکه',
# 							mesghal: 'مثقال طلا'
# 						};
# 						for (k in mobile_quickview_items) {
# 							var mqi = mobile_quickview_items[k];
# 							mobile_quickview += '<tr class="pointer" onclick="window.location=\'profile/' + k + '\'" data-market-row="' + k + '">' +
# 								'<th>' + mqi + '</th>' +
# 								'<td></td>' +
# 								'<td></td>' +
# 								'<td></td>' +
# 								'<td></td>' +
# 								'<td></td>' +
# 								'<td class="chart-td"><a data-tooltip="نمودار" class="chart-icon" target="_blank" href="profile/' + k + '"></a></td>' +
# 								'</tr>';
# 						}
#
# 						// $('.mobile-quickview tbody').html(mobile_quickview);
# 					}
#
# 				});
# 			</script>
# <div class="bottom-left-ad"></div>
# <div class="bottom-right-ad"></div>
# <div id="tgju-notification">
# <div class="tgju-notification-icon">
# <img src="https://static.accessban.com//views/default/images/notification-modal-icon.png" alt="notification">
# </div>
# <div class="tgju-notification-content">
# <h2> آیا مایلید از نوسانات بازار آگاه شوید؟ </h2>
# <span> دریافت هشدار در نوسانات قیمت طلا، سکه، دلار، اونس، نفت، بورس و بیت کوین </span>
# <div class="tgju-notification-buttons">
# <button type="button" class="b-danger" onclick="requestPermission()">بله</button>
# <button type="button" class="b-default" onclick="exit_notification_modal()">خیر</button>
# </div>
# </div>
# </div>
#
#
#
#
# <script data-dashboard-remove="true">
# 		var messaging = null;
#
# 		function exit_notification_modal() {
# 			var element = document.getElementById("tgju-notification");
# 			element.classList.remove("active");
# 			createCookie("tgju-notification",true,1);
# 		}
#
# 		function requestPermission() {
# 			Notification.requestPermission().then((permission) => {
# 				if (permission === "granted") {
# 					// Hide Permission Modal
# 					var element = document.getElementById("tgju-notification");
# 					element.classList.remove("active");
# 					resetUI();
# 				}
# 			});
# 			// [END request_permission]
# 		}
#
# 		function resetUI() {
#
# 			showToken("loading...");
# 			// [START get_token]
# 			// Get Instance ID token. Initially this makes a network call, once retrieved
# 			// subsequent calls to getToken will return from cache.
# 			messaging.getToken().then((currentToken) => {
# 				if (currentToken) {
# 					window.localStorage.setItem("fcm-token", currentToken);
# 					sendTokenToServer(currentToken);
# 				} else {
# 					// Show permission request.
# 					// Show permission UI.
# 					updateUIForPushPermissionRequired();
# 					// setTokenSentToServer(false);
# 				}
# 			}).catch((err) => {
# 				showToken("Error retrieving Instance ID token. ", err);
# 				// setTokenSentToServer(false);
# 			});
# 			// [END get_token]
# 		}
#
# 		function showToken(currentToken) {
# 			// Show token in //console and UI.
# 		}
#
# 		// Send the Instance ID token your application server, so that it can:
# 		// - send messages back to this app
# 		// - subscribe/unsubscribe the token from topics
# 		function sendTokenToServer(currentToken) {
# 			// if (!isTokenSentToServer()) {
# 				$.ajax({
# 					url: "https://dashboard-api.accessban.com/v1/firebase/init",
# 					type: "get",
# 					data: { token: currentToken, location: location.href },
# 					success: function(data) {
# 						console.log("Has Sent");
# 					},
# 				});
# 				// setTokenSentToServer(true);
# 			// } else {
# 			// }
# 		}
#
# 		$(document).ready(function() {
# 			// Check is the User Allowed
# 			// if (!isTokenSentToServer()) {
# 				// $("#notification_permission").modal("show");
# 			if (typeof(Notification) !== 'undefined' && Notification.permission !== 'granted' && !readCookie("tgju-notification")) {
# 				var element = document.getElementById("tgju-notification");
# 				element.classList.add("active");
# 			}
# 			// }
#
# 			// ---------------------------------------------
# 			var firebaseConfig = {
# 				apiKey: "AIzaSyBdD3tE-NgevBxqVtnUcgC194EZw6Kbc7w",
# 				authDomain: "tgju-a76a7.firebaseapp.com",
# 				projectId: "tgju-a76a7",
# 				storageBucket: "tgju-a76a7.appspot.com",
# 				messagingSenderId: "630010290912",
# 				appId: "1:630010290912:web:e1b9ccd5bdf99270f52685",
# 				measurementId: "G-LVBXFT5PLM"
# 			};
#
# 			// Initialize Firebase
# 			firebase.initializeApp(firebaseConfig);
# 			firebase.analytics();
#
# 			if (firebase.messaging.isSupported()) {
# 				messaging = firebase.messaging();
# 				messaging.usePublicVapidKey("BIfSF3xJlEfuw7u1eop_nOKqSoGz2_58bOg1Cqg1zAwTYY1MvdDilal3jiPl4OmOSMp8iGk1q1OLZByeIgsTAAU");
# 			}
#
# 			//requestPermission();
#
#
#
# 			// function isTokenSentToServer() {
# 			// 	return window.localStorage.getItem("sentToServer") === "1";
# 			// }
#
# 			// function setTokenSentToServer(sent) {
# 			// 	window.localStorage.setItem("sentToServer", sent ? "1" : "0");
# 			// }
#
# 			// [START refresh_token]
# 			// Callback fired if Instance ID token is updated.
# 			if (messaging) {
# 				messaging.onTokenRefresh(() => {
# 					messaging.getToken().then((refreshedToken) => {
# 						//console.log("Token refreshed.");
# 						// Indicate that the new Instance ID token has not yet been sent to the
# 						// app server.
# 						// setTokenSentToServer(false);
# 						// Send Instance ID token to app server.
# 						sendTokenToServer(refreshedToken);
# 						// [START_EXCLUDE]
# 						// Display new Instance ID token and clear UI of all previous messages.
# 						resetUI();
# 						// [END_EXCLUDE]
# 					}).catch((err) => {
# 						showToken("Unable to retrieve refreshed token ", err);
# 					});
# 				});
# 				// [END refresh_token]
# 				messaging.onMessage(function(payload) {
# 					new Notification(payload.data.title, { body: payload.data.body, icon: payload.notification.icon, dir: "rtl", lang: "FA" });
# 				});
# 			}
# 		});
#
# 		//
# 		// اخبار زیر هدر
# 		//
#
# 		var news_items = [{"id":2424272,"title":"\u0622\u06cc\u0627 \u0637\u0644\u0627 \u067e\u0627 \u0631\u0627 \u0641\u0631\u0627\u062a\u0631 \u0627\u0632 1900 \u062f\u0644\u0627\u0631 \u0645\u06cc\u200c\u06af\u0630\u0627\u0631\u062f\u061f","slug":"\u0622\u06cc\u0627-\u0637\u0644\u0627-\u067e\u0627-\u0631\u0627-\u0641\u0631\u0627\u062a\u0631-\u0627\u0632-1900-\u062f\u0644\u0627\u0631-\u0645\u06cc-\u06af\u0630\u0627\u0631\u062f","category_title":"\u0627\u062e\u0628\u0627\u0631 \u0637\u0644\u0627 \u0648 \u0633\u06a9\u0647","jalali_created_at":"\u067e\u0646\u062c\u0634\u0646\u0628\u0647 15 \u0627\u0631\u062f\u06cc\u0628\u0647\u0634\u062a 1401 \u0633\u0627\u0639\u062a 13:48"},{"id":2424271,"title":"\u06af\u0648\u0686\u06cc\u060c \u0634\u06cc\u0628\u0627\u0627\u06cc\u0646\u0648 \u0648 \u062f\u0648\u062c \u06a9\u0648\u06cc\u0646 \u0631\u0627 \u0645\u06cc\u200c\u067e\u0630\u06cc\u0631\u062f","slug":"\u06af\u0648\u0686\u06cc-\u0634\u06cc\u0628\u0627\u0627\u06cc\u0646\u0648-\u0648-\u062f\u0648\u062c-\u06a9\u0648\u06cc\u0646-\u0631\u0627-\u0645\u06cc-\u067e\u0630\u06cc\u0631\u062f","category_title":"\u0627\u062e\u0628\u0627\u0631 \u0627\u0631\u0632\u0647\u0627\u06cc \u062f\u06cc\u062c\u06cc\u062a\u0627\u0644","jalali_created_at":"\u067e\u0646\u062c\u0634\u0646\u0628\u0647 15 \u0627\u0631\u062f\u06cc\u0628\u0647\u0634\u062a 1401 \u0633\u0627\u0639\u062a 13:45"},{"id":2424270,"title":"3000 \u062f\u0644\u0627\u0631\u060c \u0647\u0645\u200c\u0686\u0646\u0627\u0646 \u0645\u0627\u0646\u0639 \u0628\u0632\u0631\u06af \u0628\u0631 \u0633\u0631 \u0631\u0627\u0647 \u0627\u062a\u0631\u06cc\u0648\u0645 ","slug":"3000-\u062f\u0644\u0627\u0631-\u0647\u0645-\u0686\u0646\u0627\u0646-\u0645\u0627\u0646\u0639-\u0628\u0632\u0631\u06af-\u0628\u0631-\u0633\u0631-\u0631\u0627\u0647-\u0627\u062a\u0631\u06cc\u0648\u0645","category_title":"\u0627\u062e\u0628\u0627\u0631 \u0627\u0631\u0632\u0647\u0627\u06cc \u062f\u06cc\u062c\u06cc\u062a\u0627\u0644","jalali_created_at":"\u067e\u0646\u062c\u0634\u0646\u0628\u0647 15 \u0627\u0631\u062f\u06cc\u0628\u0647\u0634\u062a 1401 \u0633\u0627\u0639\u062a 13:43"},{"id":2424258,"title":"\u0627\u0646\u0642\u0636\u0627\u06cc \u0645\u0639\u0627\u0645\u0644\u0627\u062a \u0622\u067e\u0634\u0646 \u0628\u06cc\u062a\u200c\u06a9\u0648\u06cc\u0646 \u062f\u0631 6 \u0645\u06cc\u061b \u06af\u0627\u0648\u0647\u0627 \u0645\u06cc\u200c\u0628\u0631\u0646\u062f \u06cc\u0627 \u062e\u0631\u0633\u200c\u0647\u0627\u061f","slug":"\u0627\u0646\u0642\u0636\u0627\u06cc-\u0645\u0639\u0627\u0645\u0644\u0627\u062a-\u0622\u067e\u0634\u0646-\u0628\u06cc\u062a-\u06a9\u0648\u06cc\u0646-\u062f\u0631-6-\u0645\u06cc-\u06af\u0627\u0648\u0647\u0627-\u0645\u06cc-\u0628\u0631\u0646\u062f-\u06cc\u0627-\u062e\u0631\u0633-\u0647\u0627","category_title":"\u0627\u062e\u0628\u0627\u0631 \u0627\u0631\u0632\u0647\u0627\u06cc \u062f\u06cc\u062c\u06cc\u062a\u0627\u0644","jalali_created_at":"\u067e\u0646\u062c\u0634\u0646\u0628\u0647 15 \u0627\u0631\u062f\u06cc\u0628\u0647\u0634\u062a 1401 \u0633\u0627\u0639\u062a 13:01"},{"id":2424251,"title":"\u0628\u06cc\u062a\u200c\u06a9\u0648\u06cc\u0646 \u0628\u0627\u06cc\u062f \u0627\u0632 40 \u0647\u0632\u0627\u0631 \u062f\u0644\u0627\u0631 \u0639\u0628\u0648\u0631 \u06a9\u0646\u062f \u062a\u0627 \u0631\u0634\u062f \u06a9\u0646\u062f","slug":"\u0628\u06cc\u062a-\u06a9\u0648\u06cc\u0646-\u0628\u0627\u06cc\u062f-\u0627\u0632-\u0628\u0627\u0644\u0627\u06cc-40-\u0647\u0632\u0627\u0631-\u062f\u0644\u0627\u0631-\u0639\u0628\u0648\u0631-\u06a9\u0646\u062f-\u062a\u0627-\u0631\u0634\u062f-\u06a9\u0646\u062f","category_title":"\u0627\u062e\u0628\u0627\u0631 \u0627\u0631\u0632\u0647\u0627\u06cc \u062f\u06cc\u062c\u06cc\u062a\u0627\u0644","jalali_created_at":"\u067e\u0646\u062c\u0634\u0646\u0628\u0647 15 \u0627\u0631\u062f\u06cc\u0628\u0647\u0634\u062a 1401 \u0633\u0627\u0639\u062a 12:58"},{"id":2424244,"title":"\u062f\u0644\u0627\u0631 \u0645\u062d\u062f\u0648\u062f\u0633\u0627\u0632 \u0641\u0636\u0627\u06cc \u0628\u0627\u0632\u0627\u0631\u0647\u062 ...
# 		var desktop_news_list = [];
# 		var mobile_news_list = [];
# 		for (var i in news_items) {
# 			var item = news_items[i];
# 			desktop_news_list.push('<li>'
# 				+ '<strong>سرخط خبرها</strong>'
# 				+ item.title
# 				+ ' <a href="/news/'+item.id+'/'+item.slug+'" target="_blank">مشاهده متن کامل خبر</a>'
# 				+ '</li>');
#
# 			mobile_news_list.push('<li>'
# 				+ '<a href="/news/'+item.id+'/'+item.slug+'" target="_blank">' + item.title + '</a>'
# 				+ ' <a class="more-button" href="/news/'+item.id+'/'+item.slug+'" target="_blank">مشاهده</a>'
# 				+ '</li>');
# 		}
#
# 		$('ul.header-breadcrumb-news-line').eq(1).html(desktop_news_list.join(''));
# 		$('ul.header-breadcrumb-news-line').eq(0).html(mobile_news_list.join(''));
#
# 		var news_header_timer;
# 		var news_header_timer_next_index;
# 		function news_header_loop(index) {
# 			var length = $('ul.header-breadcrumb-news-line').eq(0).find('li').length;
# 			news_header_timer_next_index = (index + 1) > (length - 1) ? 0 : (index + 1);
#
# 			$('ul.header-breadcrumb-news-line li').removeClass('active');
# 			$('ul.header-breadcrumb-news-line').eq(0).find('li').eq(index).addClass('active');
# 			$('ul.header-breadcrumb-news-line').eq(1).find('li').eq(index).addClass('active');
#
# 			news_header_timer = setTimeout(function() {
# 				news_header_loop(news_header_timer_next_index);
# 			}, 6 * 1000);
# 		}
# 		news_header_loop(0);
#
# 		$('ul.header-breadcrumb-news-line').hover(
# 			function() { clearTimeout(news_header_timer); },
# 			function() { news_header_timer = setTimeout(function() {
# 				news_header_loop(news_header_timer_next_index);
# 			}, 6 * 1000); },
# 		);
# 	</script>
# <script type="text/javascript">(function(){window['__CF$cv$params']={r:'7076f943091c92ab',m:'N2dUmk8qREnOk2UvIwTHR7cPkloEltKTmPunhY5jKdg-1651895240-0-AS1DzdNS4xx4B2AR5OneAsfUVj3DWgYOBfclaA7tBGfUoc3rJ5k11j4BE/S30Pe8YfmE5q8XLj0A/snnFWhMgiQYSaT8B+ArmjxEukSHKnPXxP8gfDW+FwLHLlEO0/Qhlg==',s:[0xffc7b8615c,0x970455dd32],u:'/cdn-cgi/challenge-platform/h/g'}})();</script><script defer src="https://static.cloudflareinsights.com/beacon.min.js/v652eace1692a40cfa3763df669d7439c1639079717194" integrity="sha512-Gi7xpJR8tSkrpF7aordPZQlW2DLtzUlZcumS8dMQjwDHEnw9I7ZLyiOj/6tZStRBGtGgN6ceN6cMH8z7etPGlw==" data-cf-beacon='{"rayId":"7076f943091c92ab","token":"c84d9599e9ac402299407194b03967f5","version":"2021.12.0","si":100}' crossorigin="anonymous"></script>
# </body>
# </html>

# %%
print(type(page.text))
# Out:
# <class 'str'>

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-dir="rtl" data-revision="202205078" dir="rtl" lang="fa">
#  <head>
#   <title>
#    قیمت طلا, قیمت سکه, قیمت دلار - شبکه اطلاع رسانی طلا و ارز
#   </title>
#   <meta charset="utf-8"/>
#   <script src="/cdn-cgi/apps/head/2-TH869l7meD3xSLuMby-2U21iU.js">
#   </script>
#   <link href="https://static.accessban.com" rel="preconnect"/>
#   <link href="https://call.tgju.org" rel="preconnect"/>
#   <link href="https://static.accessban.com" rel="dns-prefetch"/>
#   <link href="https://call.tgju.org" rel="dns-prefetch"/>
#   <meta content="Vandaw Parin 2.0 (vandaw.com/parin)" name="generator"/>
#   <link href="https://www.tgju.org/opensearch.xml" rel="search" title="TGJU" type="application/opensearchdescription+xml"/>
#   <base href="https://www.tgju.org/"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="#35608c" name="theme-color"/>
#   <link href="https://www.tgju.org/touch-icon-ipad.png" rel="apple-touch-icon" sizes="180x180"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="" name="description"/>
#   <meta content="" name="keywords"/>
#   <meta content="شبکه اطلاع رسانی طلا و ارز" property="og:site_name"/>
#   <meta content="قیمت طلا, قیمت سکه, قیمت دلار - شبکه اطلاع رسانی طلا و ارز" property="og:title"/>
#   <meta content="fa_IR" property="og:locale"/>
#   <meta content="https://www.tgju.org/" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <meta content="" property="og:description"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="قیمت طلا, قیمت سکه, قیمت دلار - شبکه اطلاع رسانی طلا و ارز" name="twitter:title"/>
#   <meta content="@tgjuofficial" name="twitter:site"/>
#   <meta content="@tgjuofficial" name="twitter:creator"/>
#   <meta content="" name="twitter:description"/>
#   <link href="https://www.tgju.org/" rel="canonical"/>
#   <link href="https://static.accessban.com/views/default/css/init-new.css?revision=00004414.css" rel="stylesheet"/>
#   <script data-cfasync="false" defer="" src="https://static.accessban.com/views/default/js/init.js?revision=00004414.js">
#   </script>
#   <style>
#    @font-face {
# 			font-family: iranyekan;
# 			font-style: normal;
# 			font-weight: 700;
# 			src: url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/eot/iranyekanwebbold(fanum).eot");
# 			src: url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/eot/iranyekanwebbold(fanum).eot?#iefix") format("embedded-opentype"), url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/woff2/iranyekanwebbold(fanum).woff2") format("woff2"), url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/woff/iranyekanwebbold(fanum).woff") format("woff"), url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/ttf/iranyekanwebbold(fanum).ttf") format("truetype")
# 		}
#
# 		@font-face {
# 			font-family: iranyekan;
# 			font-style: normal;
# 			font-weight: 400;
# 			src: url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/eot/iranyekanwebregular(fanum).eot");
# 			src: url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/eot/iranyekanwebregular(fanum).eot?#iefix") format("embedded-opentype"), url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/woff2/iranyekanwebregular(fanum).woff2") format("woff2"), url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/woff/iranyekanwebregular(fanum).woff") format("woff"), url("https://static.accessban.com/views/default/fonts/iranyekan/Farsi_numerals_(Non_Standard)/WebFonts/fonts/ttf/iranyekanwebregular(fanum).ttf") format("truetype")
# 		}
#
# 		@font-face {
# 			font-family: fontawesome;
# 			src: url("https://static.accessban.com/views/default/css/font-awesome-4.5.0/fonts/fontawesome-webfont.eot");
# 			src: url("https://static.accessban.com/views/default/css/font-awesome-4.5.0/fonts/fontawesome-webfont.eot?#iefix&v=4.0.3") format("embedded-opentype"), url("https://static.accessban.com/views/default/css/font-awesome-4.5.0/fonts/fontawesome-webfont.woff") format("woff"), url("https://static.accessban.com/views/default/css/font-awesome-4.5.0/fonts/fontawesome-webfont.ttf") format("truetype"), url("https://static.accessban.com/views/default/css/font-awesome-4.5.0/fonts/fontawesome-webfont.svg#fontawesomeregular") format("svg");
# 			font-weight: 400;
# 			font-style: normal
# 		}
#   </style>
#   <!--[if lt IE 9]>
# 	<script src="components/fallback/html5shiv.js"></script>
# 	<script src="components/fallback/respond.min.js"></script>
# 	<![endif]-->
#   <script type="application/ld+json">
#    {
# 				"@context": "https://schema.org/",
# 				"@type": "WebSite",
# 				"name": "شبکه اطلاع رسانی طلا و ارز",
# 				"url": "https://www.tgju.org/",
# 				"potentialAction": {
# 					"@type": "SearchAction",
# 					"target": "https://www.tgju.org/search?q={query}",
# 					"query": "required",
# 					"query-input": "required name=query"
# 				}
# 			}
#   </script>
#   <script data-dashboard-remove="true" src="https://www.gstatic.com/firebasejs/8.4.2/firebase-app.js">
#   </script>
#   <script data-dashboard-remove="true" src="https://www.gstatic.com/firebasejs/8.4.2/firebase-messaging.js">
#   </script>
#   <script data-dashboard-remove="true" src="https://www.gstatic.com/firebasejs/8.4.2/firebase-analytics.js">
#   </script>
#   <script type="application/ld+json">
#    {
# 				"@context": "https://schema.org/",
# 				"@type": "Organization",
# 				"name": "شبکه اطلاع رسانی طلا و ارز",
# 				"legalName": "شبکه اطلاع رسانی طلا و ارز",
# 				"url": "https://www.tgju.org",
# 				"@id": "https://www.tgju.org",
# 				"logo": "https://www.tgju.org/touch-icon-ipad.png",
# 				"actionableFeedbackPolicy": "https://www.tgju.org/form/report",
# 				"correctionsPolicy": "https://www.tgju.org/terms",
# 				"knowsAbout": "وب سایت قیمت ها",
# 				"publishingPrinciples": "https://www.tgju.org/terms",
# 				"alternateName": "TGJU",
# 				"foundingDate": "2011-01-01T00:00:00.000Z",
# 				"image":"https://static.accessban.com/images/tgju-sc.jpg",
# 				"email": "info@tgju.org",
# 				"description": "سامانه جامع پایش، گردآوری، پردازش و انتشار قیمت‌ها و انواع داده‌های اقتصادی و مالی از انواع بورس‌ها و بازارهای ارزی، کالایی، سهام، اوراق، فلزات و مسکوکات، انرژی، صندوق‌های سرمایه‌گذاری و ارزهای دیجیتال (رمز ارزها) در عرصه داخلی و جهانی",
# 				"telephone": "+982191010004",
# 				"address": {
# 				  "@type": "PostalAddress",
# 				  "streetAddress": "North Sohrevardi St - Kourosh St - Number 66 - Floor 6 - Unite 8",
# 				  "addressLocality": "Tehran",
# 				  "addressRegion": "TEH",
# 				  "postalCode": "1559713820",
# 				  "addressCountry": "IR"
# 				},
# 				"contactPoint": {
# 				  "@type": "ContactPoint",
# 				  "contactType": "پشتیبانی",
# 				  "telephone": "+982191014609",
# 				  "contactOption": "",
# 				  "email": [
# 					  "info@tgju.org",
# 					  "support@tgju.org",
# 					  "content@tgju.org",
# 					  "technical@tgju.org",
# 					  "sales@tgju.org",
# 					  "design@tgju.org",
# 					  "finance@tgju.org",
# 					  "admin@tgju.org"
# 				  ]
# 				},
# 				"sameAs": [
# 				  "https://www.facebook.com/TgjuSocialMedia/",
# 				  "https://twitter.com/TgjuSocialMedia",
# 				  "https://www.linkedin.com/company/tgjusocialmedia",
# 				  "https://www.instagram.com/tgjusocialmedia/",
# 				  "https://www.tiktok.com/@tgjusocial",
# 				  "https://www.twitch.tv/tgjusocialmedia",
# 				  "https://www.reddit.com/user/TgjuSocialMedia",
# 				  "http://tgjusocialmedia.tumblr.com/",
# 				  "https://www.pinterest.com/TgjuSocialMedia/",
# 				  "https://vimeo.com/tgjusocialmedia",
# 				  "https://www.youtube.com/channel/UCGSWju3USoS_JuOtVnu8I9Q"
# 				  ]
# 			  }
#   </script>
#   <link href="https://static.accessban.com/views/default/images/favicon.ico" rel="shortcut icon"/>
#   <script data-cfasync="false">
#    function trans(key) {
# 	var translations = {
# 		'profile.loading': "در حال بارگزاری ...",
# 		'master.search-placeholder-all': "عبارتی را برای جستجو وارد نمایید ...",
# 		'master.search-placeholder-others': "جستجو در",
# 		'world_market.in': "در",
# 		'master.bazare_dakheli': "بازار داخلی",
# 		'master.bazare_jahani': "بازار جهانی",
# 		'master.profile': "پروفایل",
# 		'profile.history': "تاریخچه",
# 		'headermenu.gm2_2': "شاخص‌های اقتصادی",
# 		'profile.technical': "تکنیکال",
# 		'diagrams.bazar_khordeforooshi': "بازارهای خرده فروشی",
# 		'master.search-akhbar_va_maghalat': "اخبار و مقالات",
# 		'master.rahnama_va_amozesh': "راهنما و آموزش",
# 		'profile.chart': "نمودار",
# 		'master.your_search_title_was_not_found': "عنوان جستجو شده شما یافت نشد"
# 	};
#
# 	return ( typeof translations[key] != 'undefined' ) ? translations[key] : key;
# }
# 		var hide_items_str = 'transfer_usd,transfer_usd2,transfer_eur,transfer_eur2,transfer_gbp,transfer_aed,transfer_cny,transfer_myr,transfer_try,transfer_try2,transfer_cad,transfer_aud,transfer_nzd,transfer_jpy,transfer_rub,transfer_inr,transfer_sek,transfer_chf,transfer_omr,transfer_kwd,transfer_turkey_dollar,transfer_afghan_dollar,transfer_georgia_dollar,price_dollar_sm_future,price_dollar_afshar_future,price_dollar_sm,price_dollar_afshar,price_eur_ex,price_dollar_ex,price_dollar_future,price_mashhad_dollar,price_shiraz_dollar,price_marivan_dollar,price_baneh_dollar,price_piranshahr_dollar,price_istanbul_dollar,price_dubai_dollar,price_tbilisi_dollar,gold_checkout,coin_checkout,nima_buy_chf,nima_buy_gbp,nima_buy_cad,nima_buy_sek,nima_buy_nok,nima_buy_azn,nima_sell_sek,nima_sell_nok,nima_sell_azn,price_bam,price_bch,price_awg,price_btn,price_cdf,price_crc,price_cve,price_cyp,price_eos,price_etc,price_gnt';
# 		window.hide_items = hide_items_str.split(',');
#
# 		var is_dark_excluded = false;
# 		var is_darkmode = decodeURIComponent(document.cookie).indexOf('dark-mode-enabled=true') !== -1;
# 		if ( is_darkmode && !is_dark_excluded ) {
# 			document.getElementsByTagName('html')[0].className += ' dark';
# 		}
#
# 		window.is_darkmode = function () {
# 			return document.querySelector('html').classList.contains('dark');
# 		}
#
# 		var site_name = 'tgju';
# 		var site_mode = 'main';
#
#
# 					var popup_ad = {
# 						url: "https://www.instagram.com/tgjusocialmedia/",
# 						img: "https://static.accessban.com/advertisement/mbs291afet5x.gif",
# 						width: "640px"
# 					};
#
# 					var floating_ad = false;
#
# 		/**
# 		 * کد عمومی آگهی
# 		 */
# 		var advertise_to_load = [];
# 		var advertise_items = [];
# 		function advertise_region(place_id) {
# 			advertise_to_load.push(place_id);
# 		}
# 		function advertise_show() {
# 			if (advertise_to_load && advertise_to_load.length) {
# 				$.ajax({
# 					'url': 'https://api.accessban.com/v1/advertisement/place?places=' + advertise_to_load.join(','),
# 					'success': function(result) {
# 						if (result && result.response && result.response.length) {
# 							result.response = shuffle(result.response);
# 							for(var i in result.response) {
# 								var item = result.response[i];
# 								var el = $('[data-advertise-id="'+item.type+'"]');
# 								if (el.length) {
# 									if (el.attr('data-advertise-limit')) {
# 										var limit = parseInt(el.attr('data-advertise-limit'));
#
# 										if (el.find('li').length === limit) {
# 											continue;
# 										}
# 									}
#
# 									el.append('<li data-place-name="'+ item.name +'" class="show">'
# 										+ '<a target="_blank" href="'+ item.url +'">'
# 											+ '<img src="'+ item.image +'" alt="">'
# 										+ '</a>'
# 									+ '</li>');
# 								}
# 							}
# 						}
# 					}
# 				});
# 			}
# 		}
#   </script>
#   <script>
#    var trans_loading = "در حال بارگزاری ...";
# 		var parin_lang = 'fa';
# 		window.source_price = new Object();
#
# 		var platform_info = {};
# 		var platform_info_done = false;
# 		// var url = "https://platform.tgju.org/info.php";
# 		// if (window.XDomainRequest && detectIE()) {
# 		// 	var xdr = new XDomainRequest();
# 		// 	xdr.open("GET", url, false);
# 		// 	xdr.onload = function () {
# 		// 		var res = JSON.parse(xdr.responseText);
# 		// 		if (res == null || typeof (res) == 'undefined')
# 		// 		{
# 		// 			res = JSON.parse(data.firstChild.textContent);
# 		// 		}
# 		// 		publishData(res);
# 		// 	};
# 		// 	xdr.send();
# 		// } else {
# 		// 	var xmlhttp = new XMLHttpRequest();
# 		// 	xmlhttp.onreadystatechange = function() {
# 		// 	if (xmlhttp.readyState == 4) {
# 		// 		if (xmlhttp.status == 200 || xmlhttp.status == 304) {
# 		// 		publishData(JSON.parse(xmlhttp.responseText));
# 		// 		} else {
# 		// 		setTimeout(function(){ console.log("Request failed!") }, 0);
# 		// 		}
# 		// 	}
# 		// 	}
# 		// 	xmlhttp.open("GET", url, true);
# 		// 	xmlhttp.send();
# 		// }
#
#
#
#
#
# 		// یکتانت
# 		// $(document).ready(function() {
# 		// 	if ( $(window).width() < 760 && $('#advertise-place-25').length ) {
# 		// 		(function () {
# 		// 			var now = new Date();
# 		// 			var head = document.getElementsByTagName('head')[0];
# 		// 			var script = document.createElement('script');
# 		// 			script.type = 'text/javascript';
# 		// 			script.async = true;
# 		// 			script.src =
# 		// 				'https://cdn.yektanet.com/template/bnrs/yn_bnr.min.js?v=' +
# 		// 				now.getFullYear() +
# 		// 				'0' +
# 		// 				now.getMonth() +
# 		// 				'0' +
# 		// 				now.getDate() +
# 		// 				'0' +
# 		// 				now.getHours();
# 		// 			head.appendChild(script);
# 		// 		})();
# 		// 	}
# 		// });
#
#
#
#
# 		window.WhelpConfig = {
# 			app_id: '9d382a9deaf55bb4a3c81f65e39ae260'
# 		};
#
# 		// function get_notification() {
# 		// }
#   </script>
#   <script data-cfasync="false" src="https://static.accessban.com/public/jquery-2.2.4.min.js">
#   </script>
#   <style>
#    .advertise.place-2 img,
# 		.advertise.place-2 object {
# 		    height: 190px;
# 		 }
#   </style>
#   <style>
#    @media (min-width: 1023px) {
# 			.header-statement {
# 				display: none !important;
# 			}
# 		}
# 		@media only screen and (max-width: 1023px) {
# 			.top-iwmf {
# 				display: none;
# 			}
#
# 			/*.header-statement {
# 				display: block !important;
# 			}*/
# 		}
# 		@media only screen and (max-width: 760px) {
# 			.header-statement {
# 				margin-bottom:10px ;
# 			}
# 		}
# 		.header-statement {
# 			font-size: 15px;
# 			padding: 11px;
# 			font-weight: 600;
# 			background: #f4d88f;
# 			color: #482801;
# 			position: relative;
# 		}
#
# 		.header-statement:before {
# 			content: '';
# 			display: block;
# 			background: url("https://static.accessban.com/images/icon-background-pt1.png");
# 			position: absolute;
# 			left: 0;
# 			right: 0;
# 			bottom: 0;
# 			top: 0;
# 			opacity: 0.12;
# 		}
#
# 		.header-statement-wrapper {
# 			position: relative;
# 			z-index: 1;
# 			display: flex;
# 			justify-content: center
# 		}
#
# 		.header-statement img {
# 			float: right;
# 			margin-top: 5px;
# 			margin-left: 10px;
# 		}
#
# 		.header-statement a {
# 			color: #111;
# 		}
#
# 			.header-statement a.more-button {
# 				background: rgba(0,0,0,.6);
# 				display: inline-block;
# 				margin-right: 5px;
# 				border-radius: 3px;
# 				color: white;
# 				padding: 0px 8px 1px;
# 			}
#
# 		.header-statement strong {
# 			background: rgba(100, 50, 0, 0.5);
# 			padding: 5px 7px 6px;
# 			border-radius: 4px;
# 			font-size: 14px;
# 			color: #fff;
# 			display: inline-block;
# 			line-height: 1;
# 		}
# 		@media only screen and (max-width: 760px) {
# 			table thead th .h2 a {
# 				color: #fff !important;
# 			}
# 		}
# 		@media only screen and (max-width: 500px) {
# 			.header-statement img
# 			{
# 			}
# 			.header-statement-wrapper{
# 				font-size: 11px;
# 				align-items: center;
# 				white-space: nowrap;
# 			}
# 		}
#
# 		.iwmf-text,
# 		.header-statement-wrapper
# 		{
# 			color: #482801;
# 		}
#
# 		ul.header-breadcrumb-news-line {
#
# 		}
#
# 		ul.header-breadcrumb-news-line li {
# 			display: none;
# 		}
#
# 		ul.header-breadcrumb-news-line li.active {
# 			display: block;
# 		}
#   </style>
#   <meta content="7ad9f89b-a2a1-4b97-8bf9-64cc34c54323" name="insight-app-sec-validation"/>
#   <script>
#    function viewport_size() {
# 		var win = window,
# 		doc = document,
# 		docElem = doc.documentElement,
# 		body = doc.getElementsByTagName('body')[0],
# 		x = win.innerWidth || docElem.clientWidth || body.clientWidth,
# 		y = win.innerHeight|| docElem.clientHeight|| body.clientHeight;
# 		return x;
# 	}
#   </script>
#   <script async="" src="/cdn-cgi/challenge-platform/h/g/scripts/invisible.js?ts=1651892400">
#   </script>
#  </head>
#  <body class="homepage fs-grid">
#   <img alt="" src="https://static.accessban.com/advertisement/mbs291afet5x.gif" style="display: none;"/>
#   <div data-server="2022-05-07 3:30:40" data-value="2022-05-07 3:30:40" id="server-time">
#   </div>
#   <div class="">
#    <header class="widgets header-top-tools main-tgju" id="main-header">
#     <div class="header-statement">
#      <ul class="header-breadcrumb-news-line header-statement-wrapper">
#      </ul>
#     </div>
#     <div class="header">
#      <div class="menu-btn header-bar" onclick="header_bar('click', true);">
#       <span class="lines">
#        <i>
#        </i>
#        <i>
#        </i>
#        <i>
#        </i>
#       </span>
#      </div>
#      <div class="bar-menu" onmouseover="header_bar('hover')">
#      </div>
#      <a class="sitename" href=".">
#       <div class="header-logo">
#        <div class="head-logo">
#         <img alt="TGJU" src="https://www.tgju.org/touch-icon-ipad.png"/>
#        </div>
#        <div class="header-logo-title">
#         <span class="title">
#          شبکه اطلاع رسانی
#         </span>
#         <span class="description">
#          طـــــــــــلا، ســکـــــــــــه و ارز
#         </span>
#        </div>
#       </div>
#      </a>
#      <div class="top-btn-menu">
#       <div class="top-btn-icon top-btn-icon-add">
#        <div class="top-btn-icon-i">
#        </div>
#        <div class="throb-head">
#        </div>
#       </div>
#       <div class="top-btn-menu-box" id="top-btn-menu-box">
#       </div>
#       <div class="top-btn-menu-box-bg">
#       </div>
#      </div>
#      <div class="search-res-btn">
#      </div>
#      <div class="search search-hide">
#       <div class="search-container">
#        <input class="search-input" placeholder="جستجو در سایت" type="text" value=""/>
#        <select class="search-select">
#         <option class="search-option" selected="" value="all">
#          کلیه موارد
#         </option>
#         <option class="search-option" value="markets.internal">
#          بازار داخلی
#         </option>
#         <option class="search-option" value="crypto">
#          بازار ارزهای دیجیتال
#         </option>
#         <option class="search-option" value="markets.stocks">
#          بورس
#         </option>
#         <option class="search-option" value="markets.global">
#          بازار جهانی
#         </option>
#         <option class="search-option" value="economics.country">
#          اقتصاد کشورها
#         </option>
#         <option class="search-option" value="economics.index">
#          شاخص‌های اقتصادی
#         </option>
#         <option class="search-option" value="economics.forecast">
#          پیش بینی‌ها
#         </option>
#         <option class="search-option" value="news">
#          اخبار و مقالات
#         </option>
#         <option class="search-option" value="solutions.farsi">
#          راهنما و آموزش
#         </option>
#        </select>
#        <div class="search-box-header search-box-wrapper bootstrap-fix">
#         <div class="search-box-before">
#         </div>
#         <div class="search-result row search-tabs">
#          <div class="col-12 col-md-12 col-lg-12 search-result-content" style="padding: 0 !important;">
#           <div class="search-result-content-head" style="display: none">
#            <div class="search-result-title">
#             نتیجه جستجو :
#            </div>
#            <div class="search-result-tabs">
#             <span class="result-search-tab">
#              نتایج جستجو
#             </span>
#             <span class="news-search-tab">
#              اخبار و مقالات
#             </span>
#            </div>
#           </div>
#           <div class="search-result-content-data scrollbar-min">
#           </div>
#           <div class="search-result-content-footer">
#            <a href="#" style="visibility: hidden" target="_blank">
#             <i aria-hidden="true" class="fa fa-search">
#             </i>
#             مشاهده نتیجه کامل جستجوی:
#             <span class="search-result-keyword">
#             </span>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="search-exit">
#       </div>
#      </div>
#      <div class="advertising">
#       <ul class="advertise place-header" id="advertise-place-6" style="margin-bottom: 0 !important;margin-top: 0 !important;">
#        <li class="show" data-place-name="O" data-row="0">
#         <a href="https://tabdeal.org/?utm_source=tgju&amp;utm_medium=display&amp;utm_campaign=tgju_fixbnr_brnd_asli" target="_blank">
#          <img alt="تبدیل" class="ad-hide" data-ad-img-src="https://static.accessban.com/advertisement/edsfn9k4b7z6.gif" id="ad-7lztejx1r64mcqwou0wl" src="..."/>
#         </a>
#         <script>
#          ad = document.getElementById("ad-7lztejx1r64mcqwou0wl");
# 				if ((ad.parentNode.parentNode.parentNode.className.indexOf("advertise-mobile") !== -1 && viewport_size() < 758)
# 					|| (ad.parentNode.parentNode.parentNode.className.indexOf("advertise-mobile") === -1 && viewport_size() > 758)
# 					|| (ad.parentNode.parentNode.parentNode.className.indexOf("advertise-all") !== -1)
# 				) {
# 					ad.setAttribute("src", ad.getAttribute("data-ad-img-src"));
# 					ad.setAttribute("class", "");
# 				}
#         </script>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="clearfix">
#     </div>
#     <div class="header-navbar">
#      <div class="nav-links">
#       <div class="finder">
#        <div onclick="$('#indicator-modal').show(); if ( $('#indicator-modal #columns2').html() == '' ) { diagrams_render2(); }">
#         <i aria-hidden="true" class="fa fa-th">
#         </i>
#         <span class="indicator-btn-title" style="display:inline-block;">
#          شاخص یاب
#         </span>
#        </div>
#       </div>
#       <div class="header-links header-menus">
#        <ul itemscope="" itemtype="http://www.schema.org/SiteNavigationElement">
#         <li data-name="gold" itemprop="name">
#          <a href="" itemprop="url">
#           طلا و ارز
#          </a>
#          <div class="section">
#           <div>
#            <ul itemscope="" itemtype="http://www.schema.org/SiteNavigationElement">
#             <li class="header-links-icon">
#              <span class="item-1">
#              </span>
#             </li>
#             <li>
#              <a href="gold-chart">
#               قیمت طلا
#              </a>
#              <ul>
#               <li itemprop="name">
#                <a href="gold-chart" itemprop="url">
#                 نمای کلی
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/mesghal" itemprop="url">
#                 مثقال طلا
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/geram18" itemprop="url">
#                 طلای 18 عیار
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/geram24" itemprop="url">
#                 طلای 24 عیار
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/gold_mini_size/technical" itemprop="url">
#                 طلای دست دوم
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="gold-chart" itemprop="url">
#                 مشاهده کلیه شاخص ها
#                </a>
#               </li>
#              </ul>
#              <a href="currency">
#               نرخ ارز
#              </a>
#              <ul>
#               <li itemprop="name">
#                <a href="currency" itemprop="url">
#                 نمای کلی
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_dollar_rl" itemprop="url">
#                 دلار
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_eur" itemprop="url">
#                 یورو
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_gbp" itemprop="url">
#                 پوند
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_aed" itemprop="url">
#                 درهم امارات
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="currency" itemprop="url">
#                 مشاهده سایر ارزها
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li>
#              <a href="gold-chart">
#               قیمت آبشده
#              </a>
#              <ul>
#               <li itemprop="name">
#                <a href="gold-chart" itemprop="url">
#                 نمای کلی
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/gold_futures" itemprop="url">
#                 آبشده نقدی
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/gold_melted_wholesale" itemprop="url">
#                 آبشده بنکداری
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/gold_world_futures" itemprop="url">
#                 آبشده کمتر از کیلو
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/gold_melted_transfer" itemprop="url">
#                 آبشده شنبه ای
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="gold-chart" itemprop="url">
#                 مشاهده کلیه شاخص ها
#                </a>
#               </li>
#              </ul>
#              <a href="bank">
#               ارز مبادله ای
#              </a>
#              <ul>
#               <li itemprop="name">
#                <a href="bank" itemprop="url">
#                 نمای کلی
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/bank_usd" itemprop="url">
#                 دلار
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/bank_eur" itemprop="url">
#                 یورو
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/bank_gbp" itemprop="url">
#                 پوند
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/bank_aed" itemprop="url">
#                 درهم امارات
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="bank" itemprop="url">
#                 مشاهده سایر ارزهای مبادله ای
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li>
#              <a href="coin">
#               قیمت سکه
#              </a>
#              <ul>
#               <li itemprop="name">
#                <a href="coin" itemprop="url">
#                 نمای کلی
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/sekeb" itemprop="url">
#                 سکه بهار آزادی
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/sekee" itemprop="url">
#                 سکه امامی
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/nim" itemprop="url">
#                 نیم سکه
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/rob" itemprop="url">
#                 ربع سکه
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/gerami" itemprop="url">
#                 سکه گرمی
#                </a>
#               </li>
#              </ul>
#              <a href="sana">
#               ارز سنا
#              </a>
#              <ul>
#               <li itemprop="name">
#                <a href="sana" itemprop="url">
#                 نمای کلی
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/sana_sell_usd" itemprop="url">
#                 دلار
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/sana_sell_eur" itemprop="url">
#                 یورو
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/sana_sell_gbp" itemprop="url">
#                 پوند
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/sana_sell_aed" itemprop="url">
#                 درهم امارات
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="sana" itemprop="url">
#                 مشاهده سایر ارز های سنا
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li>
#              <ul>
#               <li itemprop="name">
#                <a class="header-link-plus" href="قیمت-دلار" itemprop="url">
#                 قیمت دلار
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="diamond" itemprop="url">
#                 قیمت برلیان
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="profile/silver_999" itemprop="url">
#                 قیمت نقره
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="coin" itemprop="url">
#                 سکه در بورس
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="gold-chart" itemprop="url">
#                 طلا در بورس
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="coin" itemprop="url">
#                 قیمت سکه تاریخ پایین
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="coin" itemprop="url">
#                 قیمت سکه تک فروشی
#                </a>
#               </li>
#              </ul>
#              <a href="نرخ-ارز-نیمایی" style="margin-top: 5px;">
#               ارز نیما
#              </a>
#              <ul>
#               <li itemprop="name">
#                <a href="نرخ-ارز-نیمایی" itemprop="url">
#                 نمای کلی
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/nima_sell_usd" itemprop="url">
#                 دلار
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/nima_sell_eur" itemprop="url">
#                 یورو
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/nima_sell_gbp" itemprop="url">
#                 پوند
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/nima_sell_aed" itemprop="url">
#                 درهم امارات
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="نرخ-ارز-نیمایی" itemprop="url">
#                 مشاهده سایر حواله های ارزی
#                </a>
#               </li>
#              </ul>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </li>
#         <li data-header-links="cryptomenu" data-name="cryptomenu" itemprop="name" onmouseover="load_header_links(this, 'cryptomenu');">
#          <a href="crypto" itemprop="url">
#           ارز دیجیتال
#          </a>
#          <div class="section">
#           <div>
#           </div>
#          </div>
#         </li>
#         <li data-name="stocks" itemprop="name">
#          <a href="https://www.shakhesban.com/markets/stock" itemprop="url">
#           بورس
#          </a>
#         </li>
#         <li data-header-links="markets-new" data-name="markets" itemprop="name" onmouseover="load_header_links(this, 'markets-new');">
#          <a href="local-markets" itemprop="url">
#           بازار داخلی
#          </a>
#          <div class="section">
#           <div>
#            <ul>
#             <li class="header-links-icon header-links-icon-with-tab header-links-icon-big">
#              <div class="header-links-tabs iran-markets-tab">
#               <ul>
#                <li class="active">
#                 <a href="#" onclick="header_links_tab(this, 3, 'markets-new-1'); return false;">
#                  <span class="header-links-tabs-sprite-img" style="background-position: -704px -383px;">
#                  </span>
#                  بازار ارز
#                 </a>
#                </li>
#                <li>
#                 <a href="#" onclick="header_links_tab(this, 3, 'markets-new-2'); return false;">
#                  <span class="header-links-tabs-sprite-img" style="background-position: -733px -458px;">
#                  </span>
#                  بازار طلا و سکه
#                 </a>
#                </li>
#                <li>
#                 <a href="#" onclick="header_links_tab(this, 3, 'markets-new-3'); return false;">
#                  <span class="header-links-tabs-sprite-img" style="background-position: -325px -369px;">
#                  </span>
#                  بازار بورس
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </li>
#             <li data-header-links-tab="markets-new-1">
#              <a class="header-link-plus" href="currency">
#               نرخ ارزها
#              </a>
#              <ul itemscope="" itemtype="http://www.schema.org/SiteNavigationElement">
#               <li itemprop="name">
#                <a href="currency" itemprop="url">
#                 نمای کلی
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_dollar_rl" itemprop="url" target="_blank">
#                 دلار
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_eur" itemprop="url" target="_blank">
#                 یورو
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_aed" itemprop="url" target="_blank">
#                 درهم امارات
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_gbp" itemprop="url" target="_blank">
#                 پوند انگلیس
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_sek" itemprop="url" target="_blank">
#                 کرون سوئد
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_nok" itemprop="url" target="_blank">
#                 کرون نروژ
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="currency" itemprop="url">
#                 مشاهده کلیه ارز‌های آزاد
#                </a>
#               </li>
#              </ul>
#              <a class="header-link-plus" href="sana">
#               قیمت ارز سنا
#              </a>
#              <ul itemscope="" itemtype="http://www.schema.org/SiteNavigationElement">
#               <li itemprop="name">
#                <a href="sana" itemprop="url">
#                 نمای کلی
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/sana_sell_usd" itemprop="url">
#                 دلار
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/sana_sell_eur" itemprop="url">
#                 یورو
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/sana_sell_gbp" itemprop="url">
#                 پوند
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/sana_sell_aed" itemprop="url">
#                 درهم امارات
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/sana_sell_cad" itemprop="url">
#                 دلار کانادا
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/sana_sell_try" itemprop="url">
#                 لیر ترکیه
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="sana" itemprop="url">
#                 مشاهده کلیه ارز‌های سنا
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li data-header-links-tab="markets-new-1">
#              <a class="header-link-plus" href="currency">
#               نرخ ارزها
#              </a>
#              <ul itemscope="" itemtype="http://www.schema.org/SiteNavigationElement">
#               <li itemprop="name">
#                <a href="profile/price_jpy" itemprop="url" target="_blank">
#                 ین ژاپن
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_myr" itemprop="url" target="_blank">
#                 رینگیت مالزی
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_kwd" itemprop="url" target="_blank">
#                 دینار کویت
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_syp" itemprop="url" target="_blank">
#                 لیر سوریه
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_rub" itemprop="url" target="_blank">
#                 روبل روسیه
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_omr" itemprop="url" target="_blank">
#                 ریال عمان
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_sgd" itemprop="url" target="_blank">
#                 دلار سنگاپور
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="currency" itemprop="url">
#                 مشاهده کلیه ارز‌های آزاد
#                </a>
#               </li>
#              </ul>
#              <a class="header-link-plus" href="نرخ-ارز-نیمایی">
#               قیمت ارز نیما
#              </a>
#              <ul itemscope="" itemtype="http://www.schema.org/SiteNavigationElement">
#               <li itemprop="name">
#                <a href="sana" itemprop="url">
#                 نمای کلی
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/nima_buy_usd" itemprop="url">
#                 دلار
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/nima_buy_eur" itemprop="url">
#                 یورو
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/nima_buy_gbp" itemprop="url">
#                 پوند
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/nima_buy_aed" itemprop="url">
#                 درهم امارات
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/nima_buy_cad" itemprop="url">
#                 دلار کانادا
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/nima_buy_try" itemprop="url">
#                 لیر ترکیه
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="نرخ-ارز-نیمایی" itemprop="url">
#                 مشاهده کلیه ارزهای نیما
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li data-header-links-tab="markets-new-1">
#              <a class="header-link-plus" href="currency">
#               نرخ ارزها
#              </a>
#              <ul itemscope="" itemtype="http://www.schema.org/SiteNavigationElement">
#               <li itemprop="name">
#                <a href="profile/price_iqd" itemprop="url" target="_blank">
#                 دینار عراق
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_afn" itemprop="url" target="_blank">
#                 افغانی
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_rub" itemprop="url" target="_blank">
#                 روبل روسیه
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_azn" itemprop="url" target="_blank">
#                 منات آذربایجان
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_bhd" itemprop="url" target="_blank">
#                 دینار بحرین
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_afn" itemprop="url" target="_blank">
#                 لاری گرجستان
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/price_sar" itemprop="url" target="_blank">
#                 ریال عربستان
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="bank" itemprop="url">
#                 مشاهده کلیه ارز‌های آزاد
#                </a>
#               </li>
#              </ul>
#              <a class="header-link-plus" href="bank">
#               قیمت ارز بانکی
#              </a>
#              <ul itemscope="" itemtype="http://www.schema.org/SiteNavigationElement">
#               <li itemprop="name">
#                <a href="bank" itemprop="url">
#                 نمای کلی
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/bank_usd" itemprop="url">
#                 دلار
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/bank_eur" itemprop="url">
#                 یورو
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/bank_gbp" itemprop="url">
#                 پوند
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/bank_cny" itemprop="url">
#                 یوان چین
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/bank_try" itemprop="url">
#                 لیر ترکیه
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/bank_aed" itemprop="url">
#                 درهم امارات
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="bank" itemprop="url">
#                 مشاهده کلیه ارزهای بانکی
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li data-header-links-tab="markets-new-1">
#              <ul itemscope="" itemtype="http://www.schema.org/SiteNavigationElement">
#               <li class="active">
#                <a class="header-link-plus" href="currency">
#                 قیمت ارزهای آزاد
#                </a>
#               </li>
#               <li class="active">
#                <a class="header-link-plus" href="sana">
#                 قیمت ارزهای سنا
#                </a>
#               </li>
#               <li class="active">
#                <a class="header-link-plus" href="نرخ-ارز-نیمایی">
#                 قیمت ارزهای نیما
#                </a>
#               </li>
#               <li class="active">
#                <a class="header-link-plus" href="bank">
#                 قیمت ارز های بانکی
#                </a>
#               </li>
#               <li class="active">
#                <a class="header-link-plus" href="transfer">
#                 قیمت حوالجات ارزی
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="gold-chart" itemprop="url">
#                 قیمت طلا
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="gold-chart" itemprop="url">
#                 قیمت آبشده
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="coin" itemprop="url">
#                 قیمت سکه
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="قیمت-سکه-پارسیان" itemprop="url">
#                 قیمت سکه پارسیان
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="https://www.shakhesban.com/markets/all?flow=1" itemprop="url">
#                 بازار بورس
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="https://www.shakhesban.com/markets/all?flow=2" itemprop="url">
#                 بازار فرابورس
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="https://www.shakhesban.com/markets/index" itemprop="url">
#                 شاخص ها
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="https://www.shakhesban.com/markets/stock" itemprop="url">
#                 سهام
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="https://www.shakhesban.com/markets/fund" itemprop="url">
#                 صندوق ها
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="https://www.shakhesban.com/markets/bond" itemprop="url">
#                 اوراق
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="https://www.shakhesban.com/markets/future" itemprop="url">
#                 بازار آتی ( فیوچر )
#                </a>
#               </li>
#               <li itemprop="name">
#                <a class="header-link-plus" href="https://www.shakhesban.com/markets/option" itemprop="url">
#                 بازار اختیار معامله( آپشن )
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li data-header-links-tab="markets-new-2">
#              <a href="gold-chart">
#               قیمت طلا
#              </a>
#              <ul itemscope="" itemtype="http://www.schema.org/SiteNavigationElement">
#               <li itemprop="name">
#                <a href="profile/geram18" itemprop="url">
#                 طلای 18 عیار
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/geram24" itemprop="url">
#                 طلای 24 عیار
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/gold_740k" itemprop="url">
#                 طلای 18 عیار / 740
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/gold_mini_size" itemprop="url">
#                 طلای دست دوم
#                </a>
#               </li>
#              </ul>
#              <a href="gold-chart">
#               قیمت آبشده
#              </a>
#              <ul itemscope="" itemtype="http://www.schema.org/SiteNavigationElement">
#               <li itemprop="name">
#                <a href="profile/gold_futures" itemprop="url">
#                 آبشده نقدی
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/gold_melted_wholesale" itemprop="url">
#                 آبشده بنکداری
#                </a>
#               </li>
#               <li itemprop="name">
#                <a href="profile/gold_world_futures" itemprop="url">
#                 آبشده کمتر از کیلو
#                </a>
#               </li>
# ...
#        پشتیبانی هوشمند
#       </span>
#      </a>
#     </li>
#     <li class="side-buttons-14 side-buttons-chat">
#      <a class="a" href="javascript: void(0);" onclick="open_support_chat();" style="background: #afafaf !important;">
#       <svg style="width: 26px;fill: #fff;margin: 2px 8px;" viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg">
#        <path d="M360 144h-208C138.8 144 128 154.8 128 168S138.8 192 152 192h208C373.3 192 384 181.3 384 168S373.3 144 360 144zM264 240h-112C138.8 240 128 250.8 128 264S138.8 288 152 288h112C277.3 288 288 277.3 288 264S277.3 240 264 240zM447.1 0h-384c-35.25 0-64 28.75-64 63.1v287.1c0 35.25 28.75 63.1 64 63.1h96v83.1c0 9.836 11.02 15.55 19.12 9.7l124.9-93.7h144c35.25 0 64-28.75 64-63.1V63.1C511.1 28.75 483.2 0 447.1 0zM464 352c0 8.75-7.25 16-16 16h-160l-80 60v-60H64c-8.75 0-16-7.25-16-16V64c0-8.75 7.25-16 16-16h384c8.75 0 16 7.25 16 16V352z">
#        </path>
#       </svg>
#       <span>
#        پشتیبانی آنلاین
#       </span>
#      </a>
#     </li>
#    </ul>
#   </div>
#   <div class="modal fade" id="bug-report-modal" role="dialog" style="display: none;" tabindex="-1">
#    <div class="modal-dialog-box" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <a aria-label="Close" class="modal-close" data-dismiss="modal" href="#" onclick="$(this).parents('.modal').eq(0).toggle(); return false;">
#        <span aria-hidden="true">
#         ×
#        </span>
#       </a>
#       <div class="modal-title">
#        گزارش خطا
#       </div>
#       <div style="clear: both">
#       </div>
#      </div>
#      <div id="tgju-crm-from-33">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="parin-loading">
#    <span>
#    </span>
#   </div>
#   <script>
#    //var crypto_title_set = false;
# 				$(document).ready(function () {
# 					var transfer_usd = window.source_price['price_dollar_realtime'];
# 					var crypto_bitcoin_irr = window.source_price['crypto-bitcoin-irr'];
# 					var crypto_ethereum_irr = window.source_price['crypto-ethereum-irr'];
# 					var crypto_dash_irr = window.source_price['crypto-dash-irr'];
# 					var crypto_ripple_irr = window.source_price['crypto-ripple-irr'];
# 					var crypto_litecoin_irr = window.source_price['crypto-litecoin-irr'];
# 					var crypto_stellar_irr = window.source_price['crypto-stellar-irr'];
# 					var crypto_tether_irr = window.source_price['crypto-tether-irr'];
#
# 					/*
# 					$('table.market-table.crypto-table thead tr').each(function () {
# 						$(this).find('th').eq(1).after('<th>قیمت / ریال</th>');
# 					});
# 					$('table.market-table.crypto-table tbody tr').each(function () {
# 						var val = parseFloat($(this).find('td.nf').eq(0).text());
# 						val = Math.round(parseInt(val * transfer_usd) / 1000) * 1000;
#
# 						if ( $(this).attr('data-market-row') == 'crypto-bitcoin' ) {
# 							val = crypto_bitcoin_irr;
# 						} else if ( $(this).attr('data-market-row') == 'crypto-ethereum' ) {
# 							val = crypto_ethereum_irr;
# 						} else if ( $(this).attr('data-market-row') == 'crypto-dash' ) {
# 							val = crypto_dash_irr;
# 						} else if ( $(this).attr('data-market-row') == 'crypto-ripple' ) {
# 							val = crypto_ripple_irr;
# 						} else if ( $(this).attr('data-market-row') == 'crypto-litecoin' ) {
# 							val = crypto_litecoin_irr;
# 						} else if ( $(this).attr('data-market-row') == 'crypto-stellar' ) {
# 							val = crypto_stellar_irr;
# 						} else if ( $(this).attr('data-market-row') == 'crypto-tether' ) {
# 							val = crypto_tether_irr;
# 						}
#
# 						$(this).find('td.nf').eq(0).after('<td>' + number_format(val) + '</td>');
# 					});
#
# 					crypto_title_set = true;
# 					*/
#
# 					if ($(window).width() < 760) {
# 						// $('[data-market-row="price_dollar_rl"]').remove();
# 						// $('[data-market-row="price_dollar_dt"]').attr('data-market-row', 'price_dollar_rl');
#
# 						// -------
#
# 						$('.mobile-quickview').show();
#
# 						var mobile_quickview = '';
# 						var mobile_quickview_items = {
# 							price_dollar_rl: 'دلار',
# 							sekee: 'سکه',
# 							mesghal: 'مثقال طلا'
# 						};
# 						for (k in mobile_quickview_items) {
# 							var mqi = mobile_quickview_items[k];
# 							mobile_quickview += '<tr class="pointer" onclick="window.location=\'profile/' + k + '\'" data-market-row="' + k + '">' +
# 								'<th>' + mqi + '</th>' +
# 								'<td></td>' +
# 								'<td></td>' +
# 								'<td></td>' +
# 								'<td></td>' +
# 								'<td></td>' +
# 								'<td class="chart-td"><a data-tooltip="نمودار" class="chart-icon" target="_blank" href="profile/' + k + '"></a></td>' +
# 								'</tr>';
# 						}
#
# 						// $('.mobile-quickview tbody').html(mobile_quickview);
# 					}
#
# 				});
#   </script>
#   <div class="bottom-left-ad">
#   </div>
#   <div class="bottom-right-ad">
#   </div>
#   <div id="tgju-notification">
#    <div class="tgju-notification-icon">
#     <img alt="notification" src="https://static.accessban.com//views/default/images/notification-modal-icon.png"/>
#    </div>
#    <div class="tgju-notification-content">
#     <h2>
#      آیا مایلید از نوسانات بازار آگاه شوید؟
#     </h2>
#     <span>
#      دریافت هشدار در نوسانات قیمت طلا، سکه، دلار، اونس، نفت، بورس و بیت کوین
#     </span>
#     <div class="tgju-notification-buttons">
#      <button class="b-danger" onclick="requestPermission()" type="button">
#       بله
#      </button>
#      <button class="b-default" onclick="exit_notification_modal()" type="button">
#       خیر
#      </button>
#     </div>
#    </div>
#   </div>
#   <script data-dashboard-remove="true">
#    var messaging = null;
#
# 		function exit_notification_modal() {
# 			var element = document.getElementById("tgju-notification");
# 			element.classList.remove("active");
# 			createCookie("tgju-notification",true,1);
# 		}
#
# 		function requestPermission() {
# 			Notification.requestPermission().then((permission) => {
# 				if (permission === "granted") {
# 					// Hide Permission Modal
# 					var element = document.getElementById("tgju-notification");
# 					element.classList.remove("active");
# 					resetUI();
# 				}
# 			});
# 			// [END request_permission]
# 		}
#
# 		function resetUI() {
#
# 			showToken("loading...");
# 			// [START get_token]
# 			// Get Instance ID token. Initially this makes a network call, once retrieved
# 			// subsequent calls to getToken will return from cache.
# 			messaging.getToken().then((currentToken) => {
# 				if (currentToken) {
# 					window.localStorage.setItem("fcm-token", currentToken);
# 					sendTokenToServer(currentToken);
# 				} else {
# 					// Show permission request.
# 					// Show permission UI.
# 					updateUIForPushPermissionRequired();
# 					// setTokenSentToServer(false);
# 				}
# 			}).catch((err) => {
# 				showToken("Error retrieving Instance ID token. ", err);
# 				// setTokenSentToServer(false);
# 			});
# 			// [END get_token]
# 		}
#
# 		function showToken(currentToken) {
# 			// Show token in //console and UI.
# 		}
#
# 		// Send the Instance ID token your application server, so that it can:
# 		// - send messages back to this app
# 		// - subscribe/unsubscribe the token from topics
# 		function sendTokenToServer(currentToken) {
# 			// if (!isTokenSentToServer()) {
# 				$.ajax({
# 					url: "https://dashboard-api.accessban.com/v1/firebase/init",
# 					type: "get",
# 					data: { token: currentToken, location: location.href },
# 					success: function(data) {
# 						console.log("Has Sent");
# 					},
# 				});
# 				// setTokenSentToServer(true);
# 			// } else {
# 			// }
# 		}
#
# 		$(document).ready(function() {
# 			// Check is the User Allowed
# 			// if (!isTokenSentToServer()) {
# 				// $("#notification_permission").modal("show");
# 			if (typeof(Notification) !== 'undefined' && Notification.permission !== 'granted' && !readCookie("tgju-notification")) {
# 				var element = document.getElementById("tgju-notification");
# 				element.classList.add("active");
# 			}
# 			// }
#
# 			// ---------------------------------------------
# 			var firebaseConfig = {
# 				apiKey: "AIzaSyBdD3tE-NgevBxqVtnUcgC194EZw6Kbc7w",
# 				authDomain: "tgju-a76a7.firebaseapp.com",
# 				projectId: "tgju-a76a7",
# 				storageBucket: "tgju-a76a7.appspot.com",
# 				messagingSenderId: "630010290912",
# 				appId: "1:630010290912:web:e1b9ccd5bdf99270f52685",
# 				measurementId: "G-LVBXFT5PLM"
# 			};
#
# 			// Initialize Firebase
# 			firebase.initializeApp(firebaseConfig);
# 			firebase.analytics();
#
# 			if (firebase.messaging.isSupported()) {
# 				messaging = firebase.messaging();
# 				messaging.usePublicVapidKey("BIfSF3xJlEfuw7u1eop_nOKqSoGz2_58bOg1Cqg1zAwTYY1MvdDilal3jiPl4OmOSMp8iGk1q1OLZByeIgsTAAU");
# 			}
#
# 			//requestPermission();
#
#
#
# 			// function isTokenSentToServer() {
# 			// 	return window.localStorage.getItem("sentToServer") === "1";
# 			// }
#
# 			// function setTokenSentToServer(sent) {
# 			// 	window.localStorage.setItem("sentToServer", sent ? "1" : "0");
# 			// }
#
# 			// [START refresh_token]
# 			// Callback fired if Instance ID token is updated.
# 			if (messaging) {
# 				messaging.onTokenRefresh(() => {
# 					messaging.getToken().then((refreshedToken) => {
# 						//console.log("Token refreshed.");
# 						// Indicate that the new Instance ID token has not yet been sent to the
# 						// app server.
# 						// setTokenSentToServer(false);
# 						// Send Instance ID token to app server.
# 						sendTokenToServer(refreshedToken);
# 						// [START_EXCLUDE]
# 						// Display new Instance ID token and clear UI of all previous messages.
# 						resetUI();
# 						// [END_EXCLUDE]
# 					}).catch((err) => {
# 						showToken("Unable to retrieve refreshed token ", err);
# 					});
# 				});
# 				// [END refresh_token]
# 				messaging.onMessage(function(payload) {
# 					new Notification(payload.data.title, { body: payload.data.body, icon: payload.notification.icon, dir: "rtl", lang: "FA" });
# 				});
# 			}
# 		});
#
# 		//
# 		// اخبار زیر هدر
# 		//
#
# 		var news_items = [{"id":2424272,"title":"\u0622\u06cc\u0627 \u0637\u0644\u0627 \u067e\u0627 \u0631\u0627 \u0641\u0631\u0627\u062a\u0631 \u0627\u0632 1900 \u062f\u0644\u0627\u0631 \u0645\u06cc\u200c\u06af\u0630\u0627\u0631\u062f\u061f","slug":"\u0622\u06cc\u0627-\u0637\u0644\u0627-\u067e\u0627-\u0631\u0627-\u0641\u0631\u0627\u062a\u0631-\u0627\u0632-1900-\u062f\u0644\u0627\u0631-\u0645\u06cc-\u06af\u0630\u0627\u0631\u062f","category_title":"\u0627\u062e\u0628\u0627\u0631 \u0637\u0644\u0627 \u0648 \u0633\u06a9\u0647","jalali_created_at":"\u067e\u0646\u062c\u0634\u0646\u0628\u0647 15 \u0627\u0631\u062f\u06cc\u0628\u0647\u0634\u062a 1401 \u0633\u0627\u0639\u062a 13:48"},{"id":2424271,"title":"\u06af\u0648\u0686\u06cc\u060c \u0634\u06cc\u0628\u0627\u0627\u06cc\u0646\u0648 \u0648 \u062f\u0648\u062c \u06a9\u0648\u06cc\u0646 \u0631\u0627 \u0645\u06cc\u200c\u067e\u0630\u06cc\u0631\u062f","slug":"\u06af\u0648\u0686\u06cc-\u0634\u06cc\u0628\u0627\u0627\u06cc\u0646\u0648-\u0648-\u062f\u0648\u062c-\u06a9\u0648\u06cc\u0646-\u0631\u0627-\u0645\u06cc-\u067e\u0630\u06cc\u0631\u062f","category_title":"\u0627\u062e\u0628\u0627\u0631 \u0627\u0631\u0632\u0647\u0627\u06cc \u062f\u06cc\u062c\u06cc\u062a\u0627\u0644","jalali_created_at":"\u067e\u0646\u062c\u0634\u0646\u0628\u0647 15 \u0627\u0631\u062f\u06cc\u0628\u0647\u0634\u062a 1401 \u0633\u0627\u0639\u062a 13:45"},{"id":2424270,"title":"3000 \u062f\u0644\u0627\u0631\u060c \u0647\u0645\u200c\u0686\u0646\u0627\u0646 \u0645\u0627\u0646\u0639 \u0628\u0632\u0631\u06af \u0628\u0631 \u0633\u0631 \u0631\u0627\u0647 \u0627\u062a\u0631\u06cc\u0648\u0645 ","slug":"3000-\u062f\u0644\u0627\u0631-\u0647\u0645-\u0686\u0646\u0627\u0646-\u0645\u0627\u0646\u0639-\u0628\u0632\u0631\u06af-\u0628\u0631-\u0633\u0631-\u0631\u0627\u0647-\u0627\u062a\u0631\u06cc\u0648\u0645","category_title":"\u0627\u062e\u0628\u0627\u0631 \u0627\u0631\u0632\u0647\u0627\u06cc \u062f\u06cc\u062c\u06cc\u062a\u0627\u0644","jalali_created_at":"\u067e\u0646\u062c\u0634\u0646\u0628\u0647 15 \u0627\u0631\u062f\u06cc\u0628\u0647\u0634\u062a 1401 \u0633\u0627\u0639\u062a 13:43"},{"id":2424258,"title":"\u0627\u0646\u0642\u0636\u0627\u06cc \u0645\u0639\u0627\u0645\u0644\u0627\u062a \u0622\u067e\u0634\u0646 \u0628\u06cc\u062a\u200c\u06a9\u0648\u06cc\u0646 \u062f\u0631 6 \u0645\u06cc\u061b \u06af\u0627\u0648\u0647\u0627 \u0645\u06cc\u200c\u0628\u0631\u0646\u062f \u06cc\u0627 \u062e\u0631\u0633\u200c\u0647\u0627\u061f","slug":"\u0627\u0646\u0642\u0636\u0627\u06cc-\u0645\u0639\u0627\u0645\u0644\u0627\u062a-\u0622\u067e\u0634\u0646-\u0628\u06cc\u062a-\u06a9\u0648\u06cc\u0646-\u062f\u0631-6-\u0645\u06cc-\u06af\u0627\u0648\u0647\u0627-\u0645\u06cc-\u0628\u0631\u0646\u062f-\u06cc\u0627-\u062e\u0631\u0633-\u0647\u0627","category_title":"\u0627\u062e\u0628\u0627\u0631 \u0627\u0631\u0632\u0647\u0627\u06cc \u062f\u06cc\u062c\u06cc\u062a\u0627\u0644","jalali_created_at":"\u067e\u0646\u062c\u0634\u0646\u0628\u0647 15 \u0627\u0631\u062f\u06cc\u0628\u0647\u0634\u062a 1401 \u0633\u0627\u0639\u062a 13:01"},{"id":2424251,"title":"\u0628\u06cc\u062a\u200c\u06a9\u0648\u06cc\u0646 \u0628\u0627\u06cc\u062f \u0627\u0632 40 \u0647\u0632\u0627\u0631 \u062f\u0644\u0627\u0631 \u0639\u0628\u0648\u0631 \u06a9\u0646\u062f \u062a\u0627 \u0631\u0634\u062f \u06a9\u0646\u062f","slug":"\u0628\u06cc\u062a-\u06a9\u0648\u06cc\u0646-\u0628\u0627\u06cc\u062f-\u0627\u0632-\u0628\u0627\u0644\u0627\u06cc-40-\u0647\u0632\u0627\u0631-\u062f\u0644\u0627\u0631-\u0639\u0628\u0648\u0631-\u06a9\u0646\u062f-\u062a\u0627-\u0631\u0634\u062f-\u06a9\u0646\u062f","category_title":"\u0627\u062e\u0628\u0627\u0631 \u0627\u0631\u0632\u0647\u0627\u06cc \u062f\u06cc\u062c\u06cc\u062a\u0627\u0644","jalali_created_at":"\u067e\u0646\u062c\u0634\u0646\u0628\u0647 15 \u0627\u0631\u062f\u06cc\u0628\u0647\u0634\u062a 1401 \u0633\u0627\u0639\u062a 12:58"},{"id":2424244,"title":"\u062f\u0644\u0627\u0631 \u0645\u062d\u062f\u0648\u062f\u0633\u0627\u0632 \u0641\u0636\u0627\u06cc \u0628\u0627\u0632\u0627\u0631\u0647\u062 ...
# 		var desktop_news_list = [];
# 		var mobile_news_list = [];
# 		for (var i in news_items) {
# 			var item = news_items[i];
# 			desktop_news_list.push('<li>'
# 				+ '<strong>سرخط خبرها</strong>'
# 				+ item.title
# 				+ ' <a href="/news/'+item.id+'/'+item.slug+'" target="_blank">مشاهده متن کامل خبر</a>'
# 				+ '</li>');
#
# 			mobile_news_list.push('<li>'
# 				+ '<a href="/news/'+item.id+'/'+item.slug+'" target="_blank">' + item.title + '</a>'
# 				+ ' <a class="more-button" href="/news/'+item.id+'/'+item.slug+'" target="_blank">مشاهده</a>'
# 				+ '</li>');
# 		}
#
# 		$('ul.header-breadcrumb-news-line').eq(1).html(desktop_news_list.join(''));
# 		$('ul.header-breadcrumb-news-line').eq(0).html(mobile_news_list.join(''));
#
# 		var news_header_timer;
# 		var news_header_timer_next_index;
# 		function news_header_loop(index) {
# 			var length = $('ul.header-breadcrumb-news-line').eq(0).find('li').length;
# 			news_header_timer_next_index = (index + 1) > (length - 1) ? 0 : (index + 1);
#
# 			$('ul.header-breadcrumb-news-line li').removeClass('active');
# 			$('ul.header-breadcrumb-news-line').eq(0).find('li').eq(index).addClass('active');
# 			$('ul.header-breadcrumb-news-line').eq(1).find('li').eq(index).addClass('active');
#
# 			news_header_timer = setTimeout(function() {
# 				news_header_loop(news_header_timer_next_index);
# 			}, 6 * 1000);
# 		}
# 		news_header_loop(0);
#
# 		$('ul.header-breadcrumb-news-line').hover(
# 			function() { clearTimeout(news_header_timer); },
# 			function() { news_header_timer = setTimeout(function() {
# 				news_header_loop(news_header_timer_next_index);
# 			}, 6 * 1000); },
# 		);
#   </script>
#   <script type="text/javascript">
#    (function(){window['__CF$cv$params']={r:'7076f943091c92ab',m:'N2dUmk8qREnOk2UvIwTHR7cPkloEltKTmPunhY5jKdg-1651895240-0-AS1DzdNS4xx4B2AR5OneAsfUVj3DWgYOBfclaA7tBGfUoc3rJ5k11j4BE/S30Pe8YfmE5q8XLj0A/snnFWhMgiQYSaT8B+ArmjxEukSHKnPXxP8gfDW+FwLHLlEO0/Qhlg==',s:[0xffc7b8615c,0x970455dd32],u:'/cdn-cgi/challenge-platform/h/g'}})();
#   </script>
#   <script crossorigin="anonymous" data-cf-beacon='{"rayId":"7076f943091c92ab","token":"c84d9599e9ac402299407194b03967f5","version":"2021.12.0","si":100}' defer="" integrity="sha512-Gi7xpJR8tSkrpF7aordPZQlW2DLtzUlZcumS8dMQjwDHEnw9I7ZLyiOj/6tZStRBGtGgN6ceN6cMH8z7etPGlw==" src="https://static.cloudflareinsights.com/beacon.min.js/v652eace1692a40cfa3763df669d7439c1639079717194">
#   </script>
#  </body>
# </html>

# %%
s = soup.find_all('span', {'class' : 'info-price'})

# %%
s
# Out:
# [<span class="info-price">1,529,717.5</span>,
#  <span class="info-price">1,883.40</span>,
#  <span class="info-price">56,590,000</span>,
#  <span class="info-price">13,072,000</span>,
#  <span class="info-price">131,940,000</span>,
#  <span class="info-price">257,095</span>,
#  <span class="info-price">113.22</span>,
#  <span class="info-price">288,270</span>,
#  <span class="info-price">35932.13</span>]

# %%
for _ in s:
    print(_.text)
# Out:
# 1,529,717.5
# 1,883.40
# 56,590,000
# 13,072,000
# 131,940,000
# 257,095
# 113.22
# 288,270
# 35932.13

# %%
s = soup.find('tr', {'data-market-row' : 'gc3'})

# %%
s = soup.find('tr', {'data-market-row' : 'gc3'})

# %%
s
# Out:
# <tr class="pointer" data-market-row="gc3" data-price="33,100" data-title="" onclick="window.location='profile/gc3'">
# <th>صندوق طلای مفید</th>
# <td class="nf">33,100</td>
# <td class="nf"><span class="">(0%) 0</span></td>
# <td>33,000</td>
# <td>33,149</td>
# <td>۱۲ اردیبهشت</td>
# <td class="chart-td"><a class="chart-icon" data-tooltip="نمودار" href="profile/gc3" target="_blank"></a></td>
# </tr>

# %%
s.td.text
# Out:
# '33,100'
